# %%
#-*- coding:utf-8 –*-
from apriori import apriori
from apriori import generateRules
import re

if __name__ == '__main__':
    #myDat = [ [ 1, 3, 4 ], [ 2, 3, 5 ], [ 1, 2, 3, 5 ], [ 2, 5 ] ]
    myDat=[]
    #L, suppData = apriori(myDat, 0.5)
    #rules = generateRules(L, suppData, minConf=0.7)
    #print 'rules:\n', rules
    with open("./xss-train.txt", 'r', encoding='utf-8') as f:
        for line in f:
            #/discuz?q1=0&q3=0&q2=0%3Ciframe%20src=http://xxooxxoo.js%3E
            index=line.find("?")
            if index>0:
                line=line[index+1:len(line)]
                #print line
                tokens=re.split('\=|&|\?|\%3e|\%3c|\%3E|\%3C|\%20|\%22|<|>|\\n|\(|\)|\'|\"|;|:|,|\%28|\%29',line)
                #print "token:"
                #print tokens
                myDat.append(tokens)
        f.close()

    L, suppData = apriori(myDat, 0.15)
    rules = generateRules(L, suppData, minConf=0.6)
    #print 'rules:\n', rules# -*- coding:utf-8 -*-

# %%
import sys
import urllib
import urllib.parse
import re
from hmmlearn import hmm
import numpy as np
from sklearn.externals import joblib
import html.parser
import nltk


#处理参数值的最小长度
MIN_LEN=6

#状态个数
N=10
#最大似然概率阈值
T=-200
#字母
#数字 1
#<>,:"'
#其他字符2
SEN=['<','>',',',':','\'','/',';','"','{','}','(',')']

def ischeck(str):
    if re.match(r'^(http)',str):
        return False
    for i, c in enumerate(str):
        if ord(c) > 127 or ord(c) < 31:
            return False
        if c in SEN:
            return True
        #排除中文干扰 只处理127以内的字符


    return False

def etl(str):
    vers=[]
    for i, c in enumerate(str):
        c=c.lower()
        if   ord(c) >= ord('a') and  ord(c) <= ord('z'):
            vers.append([ord(c)])
        elif ord(c) >= ord('0') and  ord(c) <= ord('9'):
            vers.append([1])
        elif c in SEN:
            vers.append([ord(c)])
        else:
            vers.append([2])

    #print vers
    return np.array(vers)

def do_str(line):
    words=nltk.word_tokenize(line)
    print  (words)

def main(filename):
    X = [[0]]
    X_lens = [1]
    with open(filename, 'r', encoding='utf-8') as f:
        for line in f:
            line=line.strip('\n')
            #url解码
            line=urllib.parse.unquote(line)
            #处理html转义字符
            h = html.parser.HTMLParser()
            line=h.unescape(line)
            if len(line) >= MIN_LEN:
                print ("Learning xss query param:(%s)" % line)
                do_str(line)

            #X=np.concatenate( [X,vers])
            #X_lens.append(len(vers))


    #print X
    #remodel = hmm.GaussianHMM(n_components=N, covariance_type="full", n_iter=100)
    #remodel.fit(X,X_lens)
    #joblib.dump(remodel, "xss-train.pkl")

    #return remodel

def test(remodel,filename):
    with open(filename, 'r', encoding='utf-8') as f:
        for line in f:
            # 切割参数
            result = urlparse.urlparse(line)
            # url解码
            query = urllib.unquote(result.query)
            params = urllib.parse.parse_qsl(query, True)

            for k, v in params:

                if ischeck(v) and len(v) >=N :
                    vers = etl(v)
                    pro = remodel.score(vers)
                    #print  "CHK SCORE:(%d) QUREY_PARAM:(%s) XSS_URL:(%s) " % (pro, v, line)
                    if pro >= T:
                        print  ("SCORE:(%d) QUREY_PARAM:(%s) XSS_URL:(%s) " % (pro,v,line))
                        #print line



if __name__ == '__main__':
    #remodel=main(sys.argv[1])
    #test(remodel,sys.argv[2])
    #nltk.download()
    main("./xss-train.txt")
    #main(sys.argv[1])
# Out:
# C:\Users\18791\Anaconda3\lib\site-packages\ipykernel\__main__.py:68: DeprecationWarning: The unescape method is deprecated and will be removed in 3.5, use html.unescape() instead.
# Learning xss query param:(<!DOCTYPE html>)
# ['<', '!', 'DOCTYPE', 'html', '>']
# Learning xss query param:(<html lang="en">)
# ['<', 'html', 'lang=', "''", 'en', "''", '>']
# Learning xss query param:(  <head>)
# ['<', 'head', '>']
# Learning xss query param:(    <meta charset="utf-8">)
# ['<', 'meta', 'charset=', "''", 'utf-8', "''", '>']
# Learning xss query param:(  <link rel="dns-prefetch" href="https://assets-cdn.github.com">)
# ['<', 'link', 'rel=', "''", 'dns-prefetch', "''", 'href=', "''", 'https', ':', '//assets-cdn.github.com', "''", '>']
# Learning xss query param:(  <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">)
# ['<', 'link', 'rel=', "''", 'dns-prefetch', "''", 'href=', "''", 'https', ':', '//avatars0.githubusercontent.com', "''", '>']
# Learning xss query param:(  <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">)
# ['<', 'link', 'rel=', "''", 'dns-prefetch', "''", 'href=', "''", 'https', ':', '//avatars1.githubusercontent.com', "''", '>']
# Learning xss query param:(  <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">)
# ['<', 'link', 'rel=', "''", 'dns-prefetch', "''", 'href=', "''", 'https', ':', '//avatars2.githubusercontent.com', "''", '>']
# Learning xss query param:(  <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">)
# ['<', 'link', 'rel=', "''", 'dns-prefetch', "''", 'href=', "''", 'https', ':', '//avatars3.githubusercontent.com', "''", '>']
# Learning xss query param:(  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">)
# ['<', 'link', 'rel=', "''", 'dns-prefetch', "''", 'href=', "''", 'https', ':', '//github-cloud.s3.amazonaws.com', "''", '>']
# Learning xss query param:(  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">)
# ['<', 'link', 'rel=', "''", 'dns-prefetch', "''", 'href=', "''", 'https', ':', '//user-images.githubusercontent.com/', "''", '>']
# Learning xss query param:(  <link crossorigin="anonymous" href="https://assets-cdn.github.com/assets/frameworks-c9193575f18b28be82c0a963e144ff6fa7a809dd8ae003a1d1e5979bed3f7f00.css" integrity="sha256-yRk1dfGLKL6CwKlj4UT/b6eoCd2K4AOh0eWXm+0/fwA=" media="all" rel="stylesheet" />)
# ['<', 'link', 'crossorigin=', "''", 'anonymous', "''", 'href=', "''", 'https', ':', '//assets-cdn.github.com/assets/frameworks-c9193575f18b28be82c0a963e144ff6fa7a809dd8ae003a1d1e5979bed3f7f00.css', "''", 'integrity=', "''", 'sha256-yRk1dfGLKL6CwKlj4UT/b6eoCd2K4AOh0eWXm+0/fwA=', "''", 'media=', "''", 'all', "''", 'rel=', "''", 'stylesheet', "''", '/', '>']
# Learning xss query param:(  <link crossorigin="anonymous" href="https://assets-cdn.github.com/assets/github-1214f71e8309b7d4dab489c2765c4de1523517be4c68b861a78d93c8e840648e.css" integrity="sha256-EhT3HoMJt9TatInCdlxN4VI1F75MaLhhp42TyOhAZI4=" media="all" rel="stylesheet" />)
# ['<', 'link', 'crossorigin=', "''", 'anonymous', "''", 'href=', "''", 'https', ':', '//assets-cdn.github.com/assets/github-1214f71e8309b7d4dab489c2765c4de1523517be4c68b861a78d93c8e840648e.css', "''", 'integrity=', "''", 'sha256-EhT3HoMJt9TatInCdlxN4VI1F75MaLhhp42TyOhAZI4=', "''", 'media=', "''", 'all', "''", 'rel=', "''", 'stylesheet', "''", '/', '>']
# Learning xss query param:(  <meta name="viewport" content="width=device-width">)
# ['<', 'meta', 'name=', "''", 'viewport', "''", 'content=', "''", 'width=device-width', "''", '>']
# Learning xss query param:(  <title>1book/xss-train.txt at master · duoergun0729/1book</title>)
# ['<', 'title', '>', '1book/xss-train.txt', 'at', 'master', '·', 'duoergun0729/1book', '<', '/title', '>']
# Learning xss query param:(  <link rel="search" type="application/opensearchdescription+xml" href="/opensearch.xml" title="GitHub">)
# ['<', 'link', 'rel=', "''", 'search', "''", 'type=', "''", 'application/opensearchdescription+xml', "''", 'href=', "''", '/opensearch.xml', "''", 'title=', "''", 'GitHub', "''", '>']
# Learning xss query param:(  <link rel="fluid-icon" href="https://github.com/fluidicon.png" title="GitHub">)
# ['<', 'link', 'rel=', "''", 'fluid-icon', "''", 'href=', "''", 'https', ':', '//github.com/fluidicon.png', "''", 'title=', "''", 'GitHub', "''", '>']
# Learning xss query param:(  <meta property="fb:app_id" content="1401488693436528">)
# ['<', 'meta', 'property=', "''", 'fb', ':', 'app_id', "''", 'content=', "''", '1401488693436528', "''", '>']
# Learning xss query param:(    <meta content="https://avatars0.githubusercontent.com/u/26346806?s=400&v=4" property="og:image" /><meta content="GitHub" property="og:site_name" /><meta content="object" property="og:type" /><meta content="duoergun0729/1book" property="og:title" /><meta content="https://github.com/duoergun0729/1book" property="og:url" /><meta content="1book - 《Web安全之机器学习入门》" property="og:description" />)
# ['<', 'meta', 'content=', "''", 'https', ':', '//avatars0.githubusercontent.com/u/26346806', '?', 's=400', '&', 'v=4', "''", 'property=', "''", 'og', ':', 'image', "''", '/', '>', '<', 'meta', 'content=', "''", 'GitHub', "''", 'property=', "''", 'og', ':', 'site_name', "''", '/', '>', '<', 'meta', 'content=', "''", 'object', "''", 'property=', "''", 'og', ':', 'type', "''", '/', '>', '<', 'meta', 'content=', "''", 'duoergun0729/1book', "''", 'property=', "''", 'og', ':', 'title', "''", '/', '>', '<', 'meta', 'content=', "''", 'https', ':', '//github.com/duoergun0729/1book', "''", 'property=', "''", 'og', ':', 'url', "''", '/', '>', '<', 'meta', 'content=', "''", '1book', '-', '《Web安全之机器学习入门》', "''", 'property=', "''", 'og', ':', 'description', "''", '/', '>']
# Learning xss query param:(  <link rel="assets" href="https://assets-cdn.github.com/">)
# ['<', 'link', 'rel=', "''", 'assets', "''", 'href=', "''", 'https', ':', '//assets-cdn.github.com/', "''", '>']
# Learning xss query param:(  <link rel="web-socket" href="wss://live.github.com/_sockets/VjI6MjE1ODQzMzY4OjlkMzlkMzI0OWE3NGJjZTVkNGI5OWZjODUxYmFiZjFhZmJkMzFmZjZlZjE4ZmMxMTEyYmFiMzRjODFmYmRmMmM=--396cc6099d5fbea70db6711fa5cce959bb37323b">)
# ['<', 'link', 'rel=', "''", 'web-socket', "''", 'href=', "''", 'wss', ':', '//live.github.com/_sockets/VjI6MjE1ODQzMzY4OjlkMzlkMzI0OWE3NGJjZTVkNGI5OWZjODUxYmFiZjFhZmJkMzFmZjZlZjE4ZmMxMTEyYmFiMzRjODFmYmRmMmM=', '--', '396cc6099d5fbea70db6711fa5cce959bb37323b', "''", '>']
# Learning xss query param:(  <meta name="pjax-timeout" content="1000">)
# ['<', 'meta', 'name=', "''", 'pjax-timeout', "''", 'content=', "''", '1000', "''", '>']
# Learning xss query param:(  <link rel="sudo-modal" href="/sessions/sudo_modal">)
# ['<', 'link', 'rel=', "''", 'sudo-modal', "''", 'href=', "''", '/sessions/sudo_modal', "''", '>']
# Learning xss query param:(  <meta name="request-id" content="DDAE:28E6:BBC257:14051AC:5A232C58" data-pjax-transient>)
# ['<', 'meta', 'name=', "''", 'request-id', "''", 'content=', "''", 'DDAE:28E6', ':', 'BBC257:14051AC:5A232C58', "''", 'data-pjax-transient', '>']
# Learning xss query param:(  <meta name="selected-link" value="repo_source" data-pjax-transient>)
# ['<', 'meta', 'name=', "''", 'selected-link', "''", 'value=', "''", 'repo_source', "''", 'data-pjax-transient', '>']
# Learning xss query param:(  <meta name="google-site-verification" content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU">)
# ['<', 'meta', 'name=', "''", 'google-site-verification', "''", 'content=', "''", 'KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU', "''", '>']
# Learning xss query param:(<meta name="google-site-verification" content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA">)
# ['<', 'meta', 'name=', "''", 'google-site-verification', "''", 'content=', "''", 'ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA', "''", '>']
# Learning xss query param:(<meta name="google-site-verification" content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc">)
# ['<', 'meta', 'name=', "''", 'google-site-verification', "''", 'content=', "''", 'GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc', "''", '>']
# Learning xss query param:(    <meta name="google-analytics" content="UA-3769691-2">)
# ['<', 'meta', 'name=', "''", 'google-analytics', "''", 'content=', "''", 'UA-3769691-2', "''", '>']
# Learning xss query param:(<meta content="collector.githubapp.com" name="octolytics-host" /><meta content="github" name="octolytics-app-id" /><meta content="https://collector.githubapp.com/github-external/browser_event" name="octolytics-event-url" /><meta content="DDAE:28E6:BBC257:14051AC:5A232C58" name="octolytics-dimension-request_id" /><meta content="iad" name="octolytics-dimension-region_edge" /><meta content="iad" name="octolytics-dimension-region_render" /><meta content="16672264" name="octolytics-actor-id" /><meta content="silizuo" name="octolytics-actor-login" /><meta content="32f8de58cf723be30a532ef00800feb3862dc0027d82cecf78a0b3a2fc8779a2" name="octolytics-actor-hash" />)
# ['<', 'meta', 'content=', "''", 'collector.githubapp.com', "''", 'name=', "''", 'octolytics-host', "''", '/', '>', '<', 'meta', 'content=', "''", 'github', "''", 'name=', "''", 'octolytics-app-id', "''", '/', '>', '<', 'meta', 'content=', "''", 'https', ':', '//collector.githubapp.com/github-external/browser_event', "''", 'name=', "''", 'octolytics-event-url', "''", '/', '>', '<', 'meta', 'content=', "''", 'DDAE:28E6', ':', 'BBC257:14051AC:5A232C58', "''", 'name=', "''", 'octolytics-dimension-request_id', "''", '/', '>', '<', 'meta', 'content=', "''", 'iad', "''", 'name=', "''", 'octolytics-dimension-region_edge', "''", '/', '>', '<', 'meta', 'content=', "''", 'iad', "''", 'name=', "''", 'octolytics-dimension-region_render', "''", '/', '>', '<', 'meta', 'content=', "''", '16672264', "''", 'name=', "''", 'octolytics-actor-id', "''", '/', '>', '<', 'meta', 'content=', "''", 'silizuo', "''", 'name=', "''", 'octolytics-actor-login', "''", '/', '>', '<', 'meta', 'content=', "''", '32f8de58cf723be30a532ef00800feb3862dc0027d82cecf78a0b3a2fc8779a2', "''", 'name=', "''", 'octolytics-actor-hash', "''", '/', '>']
# Learning xss query param:(<meta content="/<user-name>/<repo-name>/blob/show" data-pjax-transient="true" name="analytics-location" />)
# ['<', 'meta', 'content=', "''", '/', '<', 'user-name', '>', '/', '<', 'repo-name', '>', '/blob/show', "''", 'data-pjax-transient=', "''", 'true', "''", 'name=', "''", 'analytics-location', "''", '/', '>']
# Learning xss query param:(  <meta class="js-ga-set" name="dimension1" content="Logged In">)
# ['<', 'meta', 'class=', "''", 'js-ga-set', "''", 'name=', "''", 'dimension1', "''", 'content=', "''", 'Logged', 'In', "''", '>']
# Learning xss query param:(      <meta name="hostname" content="github.com">)
# ['<', 'meta', 'name=', "''", 'hostname', "''", 'content=', "''", 'github.com', "''", '>']
# Learning xss query param:(  <meta name="user-login" content="silizuo">)
# ['<', 'meta', 'name=', "''", 'user-login', "''", 'content=', "''", 'silizuo', "''", '>']
# Learning xss query param:(      <meta name="expected-hostname" content="github.com">)
# ['<', 'meta', 'name=', "''", 'expected-hostname', "''", 'content=', "''", 'github.com', "''", '>']
# Learning xss query param:(    <meta name="js-proxy-site-detection-payload" content="YmMwMGU4M2Y1OGJmOTI4NmM1Y2E1MjdmYzNiNzk2ZWIzYTAzNzgzNzkyNzIzN2E0NmU5ZjYwMDRjZTEyMjMwNnx7InJlbW90ZV9hZGRyZXNzIjoiNDYuMjAuMTcwLjE0MSIsInJlcXVlc3RfaWQiOiJEREFFOjI4RTY6QkJDMjU3OjE0MDUxQUM6NUEyMzJDNTgiLCJ0aW1lc3RhbXAiOjE1MTIyNTQ1NTMsImhvc3QiOiJnaXRodWIuY29tIn0=">)
# ['<', 'meta', 'name=', "''", 'js-proxy-site-detection-payload', "''", 'content=', "''", 'YmMwMGU4M2Y1OGJmOTI4NmM1Y2E1MjdmYzNiNzk2ZWIzYTAzNzgzNzkyNzIzN2E0NmU5ZjYwMDRjZTEyMjMwNnx7InJlbW90ZV9hZGRyZXNzIjoiNDYuMjAuMTcwLjE0MSIsInJlcXVlc3RfaWQiOiJEREFFOjI4RTY6QkJDMjU3OjE0MDUxQUM6NUEyMzJDNTgiLCJ0aW1lc3RhbXAiOjE1MTIyNTQ1NTMsImhvc3QiOiJnaXRodWIuY29tIn0=', "''", '>']
# Learning xss query param:(    <meta name="enabled-features" content="UNIVERSE_BANNER,FREE_TRIALS">)
# ['<', 'meta', 'name=', "''", 'enabled-features', "''", 'content=', "''", 'UNIVERSE_BANNER', ',', 'FREE_TRIALS', "''", '>']
# Learning xss query param:(  <meta name="html-safe-nonce" content="984b4f80db91fba046915c97959fe6fbbc89f651">)
# ['<', 'meta', 'name=', "''", 'html-safe-nonce', "''", 'content=', "''", '984b4f80db91fba046915c97959fe6fbbc89f651', "''", '>']
# Learning xss query param:(  <meta http-equiv="x-pjax-version" content="61c05d23545f26764725f429e94cfab4">)
# ['<', 'meta', 'http-equiv=', "''", 'x-pjax-version', "''", 'content=', "''", '61c05d23545f26764725f429e94cfab4', "''", '>']
# Learning xss query param:(      <link href="https://github.com/duoergun0729/1book/commits/master.atom" rel="alternate" title="Recent Commits to 1book:master" type="application/atom+xml">)
# ['<', 'link', 'href=', "''", 'https', ':', '//github.com/duoergun0729/1book/commits/master.atom', "''", 'rel=', "''", 'alternate', "''", 'title=', "''", 'Recent', 'Commits', 'to', '1book', ':', 'master', "''", 'type=', "''", 'application/atom+xml', "''", '>']
# Learning xss query param:(  <meta name="description" content="1book - 《Web安全之机器学习入门》">)
# ['<', 'meta', 'name=', "''", 'description', "''", 'content=', "''", '1book', '-', '《Web安全之机器学习入门》', "''", '>']
# Learning xss query param:(  <meta name="go-import" content="github.com/duoergun0729/1book git https://github.com/duoergun0729/1book.git">)
# ['<', 'meta', 'name=', "''", 'go-import', "''", 'content=', "''", 'github.com/duoergun0729/1book', 'git', 'https', ':', '//github.com/duoergun0729/1book.git', "''", '>']
# Learning xss query param:(  <meta content="26346806" name="octolytics-dimension-user_id" /><meta content="duoergun0729" name="octolytics-dimension-user_login" /><meta content="91390536" name="octolytics-dimension-repository_id" /><meta content="duoergun0729/1book" name="octolytics-dimension-repository_nwo" /><meta content="true" name="octolytics-dimension-repository_public" /><meta content="false" name="octolytics-dimension-repository_is_fork" /><meta content="91390536" name="octolytics-dimension-repository_network_root_id" /><meta content="duoergun0729/1book" name="octolytics-dimension-repository_network_root_nwo" /><meta content="false" name="octolytics-dimension-repository_explore_github_marketplace_ci_cta_shown" />)
# ['<', 'meta', 'content=', "''", '26346806', "''", 'name=', "''", 'octolytics-dimension-user_id', "''", '/', '>', '<', 'meta', 'content=', "''", 'duoergun0729', "''", 'name=', "''", 'octolytics-dimension-user_login', "''", '/', '>', '<', 'meta', 'content=', "''", '91390536', "''", 'name=', "''", 'octolytics-dimension-repository_id', "''", '/', '>', '<', 'meta', 'content=', "''", 'duoergun0729/1book', "''", 'name=', "''", 'octolytics-dimension-repository_nwo', "''", '/', '>', '<', 'meta', 'content=', "''", 'true', "''", 'name=', "''", 'octolytics-dimension-repository_public', "''", '/', '>', '<', 'meta', 'content=', "''", 'false', "''", 'name=', "''", 'octolytics-dimension-repository_is_fork', "''", '/', '>', '<', 'meta', 'content=', "''", '91390536', "''", 'name=', "''", 'octolytics-dimension-repository_network_root_id', "''", '/', '>', '<', 'meta', 'content=', "''", 'duoergun0729/1book', "''", 'name=', "''", 'octolytics-dimension-repository_network_root_nwo', "''", '/', '>', '<', 'meta', 'content=', "''", 'false', "''", 'name=', "''", 'octolytics-dimension-repository_explore_github_marketplace_ci_cta_shown', "''", '/', '>']
# Learning xss query param:(    <link rel="canonical" href="https://github.com/duoergun0729/1book/blob/master/code/xss-train.txt" data-pjax-transient>)
# ['<', 'link', 'rel=', "''", 'canonical', "''", 'href=', "''", 'https', ':', '//github.com/duoergun0729/1book/blob/master/code/xss-train.txt', "''", 'data-pjax-transient', '>']
# Learning xss query param:(  <meta name="browser-stats-url" content="https://api.github.com/_private/browser/stats">)
# ['<', 'meta', 'name=', "''", 'browser-stats-url', "''", 'content=', "''", 'https', ':', '//api.github.com/_private/browser/stats', "''", '>']
# Learning xss query param:(  <meta name="browser-errors-url" content="https://api.github.com/_private/browser/errors">)
# ['<', 'meta', 'name=', "''", 'browser-errors-url', "''", 'content=', "''", 'https', ':', '//api.github.com/_private/browser/errors', "''", '>']
# Learning xss query param:(  <link rel="mask-icon" href="https://assets-cdn.github.com/pinned-octocat.svg" color="#000000">)
# ['<', 'link', 'rel=', "''", 'mask-icon', "''", 'href=', "''", 'https', ':', '//assets-cdn.github.com/pinned-octocat.svg', "''", 'color=', "''", '#', '000000', "''", '>']
# Learning xss query param:(  <link rel="icon" type="image/x-icon" class="js-site-favicon" href="https://assets-cdn.github.com/favicon.ico">)
# ['<', 'link', 'rel=', "''", 'icon', "''", 'type=', "''", 'image/x-icon', "''", 'class=', "''", 'js-site-favicon', "''", 'href=', "''", 'https', ':', '//assets-cdn.github.com/favicon.ico', "''", '>']
# Learning xss query param:(<meta name="theme-color" content="#1e2327">)
# ['<', 'meta', 'name=', "''", 'theme-color', "''", 'content=', "''", '#', '1e2327', "''", '>']
# Learning xss query param:(  <meta name="u2f-support" content="true">)
# ['<', 'meta', 'name=', "''", 'u2f-support', "''", 'content=', "''", 'true', "''", '>']
# Learning xss query param:(  </head>)
# ['<', '/head', '>']
# Learning xss query param:(  <body class="logged-in env-production page-blob">)
# ['<', 'body', 'class=', "''", 'logged-in', 'env-production', 'page-blob', "''", '>']
# Learning xss query param:(  <div class="position-relative js-header-wrapper ">)
# ['<', 'div', 'class=', "''", 'position-relative', 'js-header-wrapper', '``', '>']
# Learning xss query param:(    <a href="#start-of-content" tabindex="1" class="bg-black text-white p-3 show-on-focus js-skip-to-content">Skip to content</a>)
# ['<', 'a', 'href=', "''", '#', 'start-of-content', "''", 'tabindex=', "''", '1', "''", 'class=', "''", 'bg-black', 'text-white', 'p-3', 'show-on-focus', 'js-skip-to-content', "''", '>', 'Skip', 'to', 'content', '<', '/a', '>']
# Learning xss query param:(    <div id="js-pjax-loader-bar" class="pjax-loader-bar"><div class="progress"></div></div>)
# ['<', 'div', 'id=', "''", 'js-pjax-loader-bar', "''", 'class=', "''", 'pjax-loader-bar', "''", '>', '<', 'div', 'class=', "''", 'progress', "''", '>', '<', '/div', '>', '<', '/div', '>']
# Learning xss query param:(        )
# []
# Learning xss query param:(<header class="Header  f5" role="banner">)
# ['<', 'header', 'class=', "''", 'Header', 'f5', "''", 'role=', "''", 'banner', "''", '>']
# Learning xss query param:(  <div class="d-flex px-3 flex-justify-between container-lg">)
# ['<', 'div', 'class=', "''", 'd-flex', 'px-3', 'flex-justify-between', 'container-lg', "''", '>']
# Learning xss query param:(    <div class="d-flex flex-justify-between">)
# ['<', 'div', 'class=', "''", 'd-flex', 'flex-justify-between', "''", '>']
# Learning xss query param:(      <a class="header-logo-invertocat" href="https://github.com/" data-hotkey="g d" aria-label="Homepage" data-ga-click="Header, go to dashboard, icon:logo">)
# ['<', 'a', 'class=', "''", 'header-logo-invertocat', "''", 'href=', "''", 'https', ':', '//github.com/', "''", 'data-hotkey=', "''", 'g', 'd', "''", 'aria-label=', "''", 'Homepage', "''", 'data-ga-click=', "''", 'Header', ',', 'go', 'to', 'dashboard', ',', 'icon', ':', 'logo', "''", '>']
# Learning xss query param:(  <svg aria-hidden="true" class="octicon octicon-mark-github" height="32" version="1.1" viewBox="0 0 16 16" width="32"><path fill-rule="evenodd" d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0 0 16 8c0-4.42-3.58-8-8-8z"/></svg>)
# ['<', 'svg', 'aria-hidden=', "''", 'true', "''", 'class=', "''", 'octicon', 'octicon-mark-github', "''", 'height=', "''", '32', "''", 'version=', "''", '1.1', "''", 'viewBox=', "''", '0', '0', '16', '16', "''", 'width=', "''", '32', "''", '>', '<', 'path', 'fill-rule=', "''", 'evenodd', "''", 'd=', "''", 'M8', '0C3.58', '0', '0', '3.58', '0', '8c0', '3.54', '2.29', '6.53', '5.47', '7.59.4.07.55-.17.55-.38', '0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01', '1.08.58', '1.23.82.72', '1.21', '1.87.87', '2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95', '0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12', '0', '0', '.67-.21', '2.2.82.64-.18', '1.32-.27', '2-.27.68', '0', '1.36.09', '2', '.27', '1.53-1.04', '2.2-.82', '2.2-.82.44', '1.1.16', '1.92.08', '2.12.51.56.82', '1.27.82', '2.15', '0', '3.07-1.87', '3.75-3.65', '3.95.29.25.54.73.54', '1.48', '0', '1.07-.01', '1.93-.01', '2.2', '0', '.21.15.46.55.38A8.013', '8.013', '0', '0', '0', '16', '8c0-4.42-3.58-8-8-8z', "''", '/', '>', '<', '/svg', '>']
# Learning xss query param:(    </div>)
# ['<', '/div', '>']
# Learning xss query param:(    <div class="HeaderMenu d-flex flex-justify-between flex-auto">)
# ['<', 'div', 'class=', "''", 'HeaderMenu', 'd-flex', 'flex-justify-between', 'flex-auto', "''", '>']
# Learning xss query param:(      <div class="d-flex">)
# ['<', 'div', 'class=', "''", 'd-flex', "''", '>']
# Learning xss query param:(            <div class="">)
# ['<', 'div', 'class=', "''", "''", '>']
# Learning xss query param:(              <div class="header-search scoped-search site-scoped-search js-site-search" role="search">)
# ['<', 'div', 'class=', "''", 'header-search', 'scoped-search', 'site-scoped-search', 'js-site-search', "''", 'role=', "''", 'search', "''", '>']
# Learning xss query param:(  <!-- '"` --><!-- </textarea></xmp> --></option></form><form accept-charset="UTF-8" action="/duoergun0729/1book/search" class="js-site-search-form" data-scoped-search-url="/duoergun0729/1book/search" data-unscoped-search-url="/search" method="get"><div style="margin:0;padding:0;display:inline"><input name="utf8" type="hidden" value="✓" /></div>)
# ['<', '!', '--', "'", "''", '`', '--', '>', '<', '!', '--', '<', '/textarea', '>', '<', '/xmp', '>', '--', '>', '<', '/option', '>', '<', '/form', '>', '<', 'form', 'accept-charset=', "''", 'UTF-8', "''", 'action=', "''", '/duoergun0729/1book/search', "''", 'class=', "''", 'js-site-search-form', "''", 'data-scoped-search-url=', "''", '/duoergun0729/1book/search', "''", 'data-unscoped-search-url=', "''", '/search', "''", 'method=', "''", 'get', "''", '>', '<', 'div', 'style=', "''", 'margin:0', ';', 'padding:0', ';', 'display', ':', 'inline', "''", '>', '<', 'input', 'name=', "''", 'utf8', "''", 'type=', "''", 'hidden', "''", 'value=', "''", '✓', "''", '/', '>', '<', '/div', '>']
# Learning xss query param:(    <label class="form-control header-search-wrapper js-chromeless-input-container">)
# ['<', 'label', 'class=', "''", 'form-control', 'header-search-wrapper', 'js-chromeless-input-container', "''", '>']
# Learning xss query param:(        <a href="/duoergun0729/1book/blob/master/code/xss-train.txt" class="header-search-scope no-underline">This repository</a>)
# ['<', 'a', 'href=', "''", '/duoergun0729/1book/blob/master/code/xss-train.txt', "''", 'class=', "''", 'header-search-scope', 'no-underline', "''", '>', 'This', 'repository', '<', '/a', '>']
# Learning xss query param:(      <input type="text")
# ['<', 'input', 'type=', "''", 'text', "''"]
# Learning xss query param:(        class="form-control header-search-input js-site-search-focus js-site-search-field is-clearable")
# ['class=', "''", 'form-control', 'header-search-input', 'js-site-search-focus', 'js-site-search-field', 'is-clearable', "''"]
# Learning xss query param:(        data-hotkey="s")
# ['data-hotkey=', "''", 's', "''"]
# Learning xss query param:(        name="q")
# ['name=', "''", 'q', "''"]
# Learning xss query param:(        value="")
# ['value=', "''", "''"]
# Learning xss query param:(        placeholder="Search")
# ['placeholder=', "''", 'Search', "''"]
# Learning xss query param:(        aria-label="Search this repository")
# ['aria-label=', "''", 'Search', 'this', 'repository', "''"]
# Learning xss query param:(        data-unscoped-placeholder="Search GitHub")
# ['data-unscoped-placeholder=', "''", 'Search', 'GitHub', "''"]
# Learning xss query param:(        data-scoped-placeholder="Search")
# ['data-scoped-placeholder=', "''", 'Search', "''"]
# Learning xss query param:(        autocapitalize="off">)
# ['autocapitalize=', "''", 'off', "''", '>']
# Learning xss query param:(        <input type="hidden" class="js-site-search-type-field" name="type" >)
# ['<', 'input', 'type=', "''", 'hidden', "''", 'class=', "''", 'js-site-search-type-field', "''", 'name=', "''", 'type', "''", '>']
# Learning xss query param:(    </label>)
# ['<', '/label', '>']
# Learning xss query param:(</form></div>)
# ['<', '/form', '>', '<', '/div', '>']
# Learning xss query param:(            </div>)
# ['<', '/div', '>']
# Learning xss query param:(          <ul class="d-flex pl-2 flex-items-center text-bold list-style-none" role="navigation">)
# ['<', 'ul', 'class=', "''", 'd-flex', 'pl-2', 'flex-items-center', 'text-bold', 'list-style-none', "''", 'role=', "''", 'navigation', "''", '>']
# Learning xss query param:(            <li>)
# ['<', 'li', '>']
# Learning xss query param:(              <a href="/pulls" aria-label="Pull requests you created" class="js-selected-navigation-item HeaderNavlink px-2" data-ga-click="Header, click, Nav menu - item:pulls context:user" data-hotkey="g p" data-selected-links="/pulls /pulls/assigned /pulls/mentioned /pulls">)
# ['<', 'a', 'href=', "''", '/pulls', "''", 'aria-label=', "''", 'Pull', 'requests', 'you', 'created', "''", 'class=', "''", 'js-selected-navigation-item', 'HeaderNavlink', 'px-2', "''", 'data-ga-click=', "''", 'Header', ',', 'click', ',', 'Nav', 'menu', '-', 'item', ':', 'pulls', 'context', ':', 'user', "''", 'data-hotkey=', "''", 'g', 'p', "''", 'data-selected-links=', "''", '/pulls', '/pulls/assigned', '/pulls/mentioned', '/pulls', "''", '>']
# Learning xss query param:(                Pull requests)
# ['Pull', 'requests']
# Learning xss query param:(</a>            </li>)
# ['<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(            <li>)
# ['<', 'li', '>']
# Learning xss query param:(              <a href="/issues" aria-label="Issues you created" class="js-selected-navigation-item HeaderNavlink px-2" data-ga-click="Header, click, Nav menu - item:issues context:user" data-hotkey="g i" data-selected-links="/issues /issues/assigned /issues/mentioned /issues">)
# ['<', 'a', 'href=', "''", '/issues', "''", 'aria-label=', "''", 'Issues', 'you', 'created', "''", 'class=', "''", 'js-selected-navigation-item', 'HeaderNavlink', 'px-2', "''", 'data-ga-click=', "''", 'Header', ',', 'click', ',', 'Nav', 'menu', '-', 'item', ':', 'issues', 'context', ':', 'user', "''", 'data-hotkey=', "''", 'g', 'i', "''", 'data-selected-links=', "''", '/issues', '/issues/assigned', '/issues/mentioned', '/issues', "''", '>']
# Learning xss query param:(                Issues)
# ['Issues']
# Learning xss query param:(</a>            </li>)
# ['<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(                <li>)
# ['<', 'li', '>']
# Learning xss query param:(                  <a href="/marketplace" class="js-selected-navigation-item HeaderNavlink px-2" data-ga-click="Header, click, Nav menu - item:marketplace context:user" data-selected-links=" /marketplace">)
# ['<', 'a', 'href=', "''", '/marketplace', "''", 'class=', "''", 'js-selected-navigation-item', 'HeaderNavlink', 'px-2', "''", 'data-ga-click=', "''", 'Header', ',', 'click', ',', 'Nav', 'menu', '-', 'item', ':', 'marketplace', 'context', ':', 'user', "''", 'data-selected-links=', "''", '/marketplace', "''", '>']
# Learning xss query param:(                    Marketplace)
# ['Marketplace']
# Learning xss query param:(</a>                </li>)
# ['<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(            <li>)
# ['<', 'li', '>']
# Learning xss query param:(              <a href="/explore" class="js-selected-navigation-item HeaderNavlink px-2" data-ga-click="Header, click, Nav menu - item:explore" data-selected-links="/explore /trending /trending/developers /integrations /integrations/feature/code /integrations/feature/collaborate /integrations/feature/ship showcases showcases_search showcases_landing /explore">)
# ['<', 'a', 'href=', "''", '/explore', "''", 'class=', "''", 'js-selected-navigation-item', 'HeaderNavlink', 'px-2', "''", 'data-ga-click=', "''", 'Header', ',', 'click', ',', 'Nav', 'menu', '-', 'item', ':', 'explore', "''", 'data-selected-links=', "''", '/explore', '/trending', '/trending/developers', '/integrations', '/integrations/feature/code', '/integrations/feature/collaborate', '/integrations/feature/ship', 'showcases', 'showcases_search', 'showcases_landing', '/explore', "''", '>']
# Learning xss query param:(                Explore)
# ['Explore']
# Learning xss query param:(</a>            </li>)
# ['<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(          </ul>)
# ['<', '/ul', '>']
# Learning xss query param:(      </div>)
# ['<', '/div', '>']
# Learning xss query param:(      <div class="d-flex">)
# ['<', 'div', 'class=', "''", 'd-flex', "''", '>']
# Learning xss query param:(        )
# []
# Learning xss query param:(<ul class="user-nav d-flex flex-items-center list-style-none" id="user-links">)
# ['<', 'ul', 'class=', "''", 'user-nav', 'd-flex', 'flex-items-center', 'list-style-none', "''", 'id=', "''", 'user-links', "''", '>']
# Learning xss query param:(  <li class="dropdown js-menu-container">)
# ['<', 'li', 'class=', "''", 'dropdown', 'js-menu-container', "''", '>']
# Learning xss query param:(    <span class="d-inline-block  px-2">)
# ['<', 'span', 'class=', "''", 'd-inline-block', 'px-2', "''", '>']
# Learning xss query param:(      )
# []
# Learning xss query param:(    </span>)
# ['<', '/span', '>']
# Learning xss query param:(  </li>)
# ['<', '/li', '>']
# Learning xss query param:(  <li class="dropdown js-menu-container">)
# ['<', 'li', 'class=', "''", 'dropdown', 'js-menu-container', "''", '>']
# Learning xss query param:(    <details class="dropdown-details details-reset js-dropdown-details d-flex px-2 flex-items-center">)
# ['<', 'details', 'class=', "''", 'dropdown-details', 'details-reset', 'js-dropdown-details', 'd-flex', 'px-2', 'flex-items-center', "''", '>']
# Learning xss query param:(      <summary class="HeaderNavlink")
# ['<', 'summary', 'class=', "''", 'HeaderNavlink', "''"]
# Learning xss query param:(         aria-label="Create new…")
# ['aria-label=', "''", 'Create', 'new…', "''"]
# Learning xss query param:(         data-ga-click="Header, create new, icon:add">)
# ['data-ga-click=', "''", 'Header', ',', 'create', 'new', ',', 'icon', ':', 'add', "''", '>']
# Learning xss query param:(        <svg aria-hidden="true" class="octicon octicon-plus float-left mr-1 mt-1" height="16" version="1.1" viewBox="0 0 12 16" width="12"><path fill-rule="evenodd" d="M12 9H7v5H5V9H0V7h5V2h2v5h5z"/></svg>)
# ['<', 'svg', 'aria-hidden=', "''", 'true', "''", 'class=', "''", 'octicon', 'octicon-plus', 'float-left', 'mr-1', 'mt-1', "''", 'height=', "''", '16', "''", 'version=', "''", '1.1', "''", 'viewBox=', "''", '0', '0', '12', '16', "''", 'width=', "''", '12', "''", '>', '<', 'path', 'fill-rule=', "''", 'evenodd', "''", 'd=', "''", 'M12', '9H7v5H5V9H0V7h5V2h2v5h5z', "''", '/', '>', '<', '/svg', '>']
# Learning xss query param:(        <span class="dropdown-caret mt-1"></span>)
# ['<', 'span', 'class=', "''", 'dropdown-caret', 'mt-1', "''", '>', '<', '/span', '>']
# Learning xss query param:(      </summary>)
# ['<', '/summary', '>']
# Learning xss query param:(      <ul class="dropdown-menu dropdown-menu-sw">)
# ['<', 'ul', 'class=', "''", 'dropdown-menu', 'dropdown-menu-sw', "''", '>']
# Learning xss query param:(        )
# []
# Learning xss query param:(<a class="dropdown-item" href="/new" data-ga-click="Header, create new repository">)
# ['<', 'a', 'class=', "''", 'dropdown-item', "''", 'href=', "''", '/new', "''", 'data-ga-click=', "''", 'Header', ',', 'create', 'new', 'repository', "''", '>']
# Learning xss query param:(  New repository)
# ['New', 'repository']
# Learning xss query param:(  <a class="dropdown-item" href="/new/import" data-ga-click="Header, import a repository">)
# ['<', 'a', 'class=', "''", 'dropdown-item', "''", 'href=', "''", '/new/import', "''", 'data-ga-click=', "''", 'Header', ',', 'import', 'a', 'repository', "''", '>']
# Learning xss query param:(    Import repository)
# ['Import', 'repository']
# Learning xss query param:(  </a>)
# ['<', '/a', '>']
# Learning xss query param:(<a class="dropdown-item" href="https://gist.github.com/" data-ga-click="Header, create new gist">)
# ['<', 'a', 'class=', "''", 'dropdown-item', "''", 'href=', "''", 'https', ':', '//gist.github.com/', "''", 'data-ga-click=', "''", 'Header', ',', 'create', 'new', 'gist', "''", '>']
# Learning xss query param:(  New gist)
# ['New', 'gist']
# Learning xss query param:(  <a class="dropdown-item" href="/organizations/new" data-ga-click="Header, create new organization">)
# ['<', 'a', 'class=', "''", 'dropdown-item', "''", 'href=', "''", '/organizations/new', "''", 'data-ga-click=', "''", 'Header', ',', 'create', 'new', 'organization', "''", '>']
# Learning xss query param:(    New organization)
# ['New', 'organization']
# Learning xss query param:(  </a>)
# ['<', '/a', '>']
# Learning xss query param:(  <div class="dropdown-divider"></div>)
# ['<', 'div', 'class=', "''", 'dropdown-divider', "''", '>', '<', '/div', '>']
# Learning xss query param:(  <div class="dropdown-header">)
# ['<', 'div', 'class=', "''", 'dropdown-header', "''", '>']
# Learning xss query param:(    <span title="duoergun0729/1book">This repository</span>)
# ['<', 'span', 'title=', "''", 'duoergun0729/1book', "''", '>', 'This', 'repository', '<', '/span', '>']
# Learning xss query param:(  </div>)
# ['<', '/div', '>']
# Learning xss query param:(    <a class="dropdown-item" href="/duoergun0729/1book/issues/new" data-ga-click="Header, create new issue">)
# ['<', 'a', 'class=', "''", 'dropdown-item', "''", 'href=', "''", '/duoergun0729/1book/issues/new', "''", 'data-ga-click=', "''", 'Header', ',', 'create', 'new', 'issue', "''", '>']
# Learning xss query param:(      New issue)
# ['New', 'issue']
# Learning xss query param:(    </a>)
# ['<', '/a', '>']
# Learning xss query param:(      </ul>)
# ['<', '/ul', '>']
# Learning xss query param:(    </details>)
# ['<', '/details', '>']
# Learning xss query param:(  </li>)
# ['<', '/li', '>']
# Learning xss query param:(  <li class="dropdown js-menu-container">)
# ['<', 'li', 'class=', "''", 'dropdown', 'js-menu-container', "''", '>']
# Learning xss query param:(    <details class="dropdown-details details-reset js-dropdown-details d-flex pl-2 flex-items-center">)
# ['<', 'details', 'class=', "''", 'dropdown-details', 'details-reset', 'js-dropdown-details', 'd-flex', 'pl-2', 'flex-items-center', "''", '>']
# Learning xss query param:(      <summary class="HeaderNavlink name mt-1")
# ['<', 'summary', 'class=', "''", 'HeaderNavlink', 'name', 'mt-1', "''"]
# Learning xss query param:(        aria-label="View profile and more")
# ['aria-label=', "''", 'View', 'profile', 'and', 'more', "''"]
# Learning xss query param:(        data-ga-click="Header, show menu, icon:avatar">)
# ['data-ga-click=', "''", 'Header', ',', 'show', 'menu', ',', 'icon', ':', 'avatar', "''", '>']
# Learning xss query param:(        <img alt="@silizuo" class="avatar float-left mr-1" src="https://avatars1.githubusercontent.com/u/16672264?s=40&v=4" height="20" width="20">)
# ['<', 'img', 'alt=', "''", '@', 'silizuo', "''", 'class=', "''", 'avatar', 'float-left', 'mr-1', "''", 'src=', "''", 'https', ':', '//avatars1.githubusercontent.com/u/16672264', '?', 's=40', '&', 'v=4', "''", 'height=', "''", '20', "''", 'width=', "''", '20', "''", '>']
# Learning xss query param:(        <span class="dropdown-caret"></span>)
# ['<', 'span', 'class=', "''", 'dropdown-caret', "''", '>', '<', '/span', '>']
# Learning xss query param:(      </summary>)
# ['<', '/summary', '>']
# Learning xss query param:(      <ul class="dropdown-menu dropdown-menu-sw">)
# ['<', 'ul', 'class=', "''", 'dropdown-menu', 'dropdown-menu-sw', "''", '>']
# Learning xss query param:(        <li class="dropdown-header header-nav-current-user css-truncate">)
# ['<', 'li', 'class=', "''", 'dropdown-header', 'header-nav-current-user', 'css-truncate', "''", '>']
# Learning xss query param:(          Signed in as <strong class="css-truncate-target">silizuo</strong>)
# ['Signed', 'in', 'as', '<', 'strong', 'class=', "''", 'css-truncate-target', "''", '>', 'silizuo', '<', '/strong', '>']
# Learning xss query param:(        </li>)
# ['<', '/li', '>']
# Learning xss query param:(        <li class="dropdown-divider"></li>)
# ['<', 'li', 'class=', "''", 'dropdown-divider', "''", '>', '<', '/li', '>']
# Learning xss query param:(        <li><a class="dropdown-item" href="/silizuo" data-ga-click="Header, go to profile, text:your profile">)
# ['<', 'li', '>', '<', 'a', 'class=', "''", 'dropdown-item', "''", 'href=', "''", '/silizuo', "''", 'data-ga-click=', "''", 'Header', ',', 'go', 'to', 'profile', ',', 'text', ':', 'your', 'profile', "''", '>']
# Learning xss query param:(          Your profile)
# ['Your', 'profile']
# Learning xss query param:(        </a></li>)
# ['<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(        <li><a class="dropdown-item" href="/silizuo?tab=stars" data-ga-click="Header, go to starred repos, text:your stars">)
# ['<', 'li', '>', '<', 'a', 'class=', "''", 'dropdown-item', "''", 'href=', "''", '/silizuo', '?', 'tab=stars', "''", 'data-ga-click=', "''", 'Header', ',', 'go', 'to', 'starred', 'repos', ',', 'text', ':', 'your', 'stars', "''", '>']
# Learning xss query param:(          Your stars)
# ['Your', 'stars']
# Learning xss query param:(        </a></li>)
# ['<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(          <li><a class="dropdown-item" href="https://gist.github.com/" data-ga-click="Header, your gists, text:your gists">Your Gists</a></li>)
# ['<', 'li', '>', '<', 'a', 'class=', "''", 'dropdown-item', "''", 'href=', "''", 'https', ':', '//gist.github.com/', "''", 'data-ga-click=', "''", 'Header', ',', 'your', 'gists', ',', 'text', ':', 'your', 'gists', "''", '>', 'Your', 'Gists', '<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(        <li class="dropdown-divider"></li>)
# ['<', 'li', 'class=', "''", 'dropdown-divider', "''", '>', '<', '/li', '>']
# Learning xss query param:(        <li><a class="dropdown-item" href="https://help.github.com" data-ga-click="Header, go to help, text:help">)
# ['<', 'li', '>', '<', 'a', 'class=', "''", 'dropdown-item', "''", 'href=', "''", 'https', ':', '//help.github.com', "''", 'data-ga-click=', "''", 'Header', ',', 'go', 'to', 'help', ',', 'text', ':', 'help', "''", '>']
# Learning xss query param:(          Help)
# ['Help']
# Learning xss query param:(        </a></li>)
# ['<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(        <li><a class="dropdown-item" href="/settings/profile" data-ga-click="Header, go to settings, icon:settings">)
# ['<', 'li', '>', '<', 'a', 'class=', "''", 'dropdown-item', "''", 'href=', "''", '/settings/profile', "''", 'data-ga-click=', "''", 'Header', ',', 'go', 'to', 'settings', ',', 'icon', ':', 'settings', "''", '>']
# Learning xss query param:(          Settings)
# ['Settings']
# Learning xss query param:(        </a></li>)
# ['<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(        <li><!-- '"` --><!-- </textarea></xmp> --></option></form><form accept-charset="UTF-8" action="/logout" class="logout-form" method="post"><div style="margin:0;padding:0;display:inline"><input name="utf8" type="hidden" value="✓" /><input name="authenticity_token" type="hidden" value="ha+8ZTDC8zpjz4kwpvjNG54jk0OdGgJUTs+NiptCk8fQ1sGw8kQU09MDsJhIMg2yGWL3D1EesjFcHIT+AuClHA==" /></div>)
# ['<', 'li', '>', '<', '!', '--', "'", "''", '`', '--', '>', '<', '!', '--', '<', '/textarea', '>', '<', '/xmp', '>', '--', '>', '<', '/option', '>', '<', '/form', '>', '<', 'form', 'accept-charset=', "''", 'UTF-8', "''", 'action=', "''", '/logout', "''", 'class=', "''", 'logout-form', "''", 'method=', "''", 'post', "''", '>', '<', 'div', 'style=', "''", 'margin:0', ';', 'padding:0', ';', 'display', ':', 'inline', "''", '>', '<', 'input', 'name=', "''", 'utf8', "''", 'type=', "''", 'hidden', "''", 'value=', "''", '✓', "''", '/', '>', '<', 'input', 'name=', "''", 'authenticity_token', "''", 'type=', "''", 'hidden', "''", 'value=', "''", 'ha+8ZTDC8zpjz4kwpvjNG54jk0OdGgJUTs+NiptCk8fQ1sGw8kQU09MDsJhIMg2yGWL3D1EesjFcHIT+AuClHA==', "''", '/', '>', '<', '/div', '>']
# Learning xss query param:(          <button type="submit" class="dropdown-item dropdown-signout" data-ga-click="Header, sign out, icon:logout">)
# ['<', 'button', 'type=', "''", 'submit', "''", 'class=', "''", 'dropdown-item', 'dropdown-signout', "''", 'data-ga-click=', "''", 'Header', ',', 'sign', 'out', ',', 'icon', ':', 'logout', "''", '>']
# Learning xss query param:(            Sign out)
# ['Sign', 'out']
# Learning xss query param:(          </button>)
# ['<', '/button', '>']
# Learning xss query param:(        </form></li>)
# ['<', '/form', '>', '<', '/li', '>']
# Learning xss query param:(      </ul>)
# ['<', '/ul', '>']
# Learning xss query param:(    </details>)
# ['<', '/details', '>']
# Learning xss query param:(  </li>)
# ['<', '/li', '>']
# Learning xss query param:(        <!-- '"` --><!-- </textarea></xmp> --></option></form><form accept-charset="UTF-8" action="/logout" class="sr-only right-0" method="post"><div style="margin:0;padding:0;display:inline"><input name="utf8" type="hidden" value="✓" /><input name="authenticity_token" type="hidden" value="A5UlM3pAwFQ59Slb1SDaaerUvEcHbkrGpEzUvR3v5a1W7FjmuMYnvYk5EPM76hrAbZXYC8tq+qO2n93JhE3Tdg==" /></div>)
# ['<', '!', '--', "'", "''", '`', '--', '>', '<', '!', '--', '<', '/textarea', '>', '<', '/xmp', '>', '--', '>', '<', '/option', '>', '<', '/form', '>', '<', 'form', 'accept-charset=', "''", 'UTF-8', "''", 'action=', "''", '/logout', "''", 'class=', "''", 'sr-only', 'right-0', "''", 'method=', "''", 'post', "''", '>', '<', 'div', 'style=', "''", 'margin:0', ';', 'padding:0', ';', 'display', ':', 'inline', "''", '>', '<', 'input', 'name=', "''", 'utf8', "''", 'type=', "''", 'hidden', "''", 'value=', "''", '✓', "''", '/', '>', '<', 'input', 'name=', "''", 'authenticity_token', "''", 'type=', "''", 'hidden', "''", 'value=', "''", 'A5UlM3pAwFQ59Slb1SDaaerUvEcHbkrGpEzUvR3v5a1W7FjmuMYnvYk5EPM76hrAbZXYC8tq+qO2n93JhE3Tdg==', "''", '/', '>', '<', '/div', '>']
# Learning xss query param:(          <button type="submit" class="dropdown-item dropdown-signout" data-ga-click="Header, sign out, icon:logout">)
# ['<', 'button', 'type=', "''", 'submit', "''", 'class=', "''", 'dropdown-item', 'dropdown-signout', "''", 'data-ga-click=', "''", 'Header', ',', 'sign', 'out', ',', 'icon', ':', 'logout', "''", '>']
# Learning xss query param:(            Sign out)
# ['Sign', 'out']
# Learning xss query param:(          </button>)
# ['<', '/button', '>']
# Learning xss query param:(</form>      </div>)
# ['<', '/form', '>', '<', '/div', '>']
# Learning xss query param:(    </div>)
# ['<', '/div', '>']
# Learning xss query param:(  </div>)
# ['<', '/div', '>']
# Learning xss query param:(</header>)
# ['<', '/header', '>']
# Learning xss query param:(      )
# []
# Learning xss query param:(  </div>)
# ['<', '/div', '>']
# Learning xss query param:(  <div id="start-of-content" class="show-on-focus"></div>)
# ['<', 'div', 'id=', "''", 'start-of-content', "''", 'class=', "''", 'show-on-focus', "''", '>', '<', '/div', '>']
# Learning xss query param:(    <div id="js-flash-container">)
# ['<', 'div', 'id=', "''", 'js-flash-container', "''", '>']
# Learning xss query param:(</div>)
# ['<', '/div', '>']
# Learning xss query param:(  <div role="main">)
# ['<', 'div', 'role=', "''", 'main', "''", '>']
# Learning xss query param:(        <div itemscope itemtype="http://schema.org/SoftwareSourceCode">)
# ['<', 'div', 'itemscope', 'itemtype=', "''", 'http', ':', '//schema.org/SoftwareSourceCode', "''", '>']
# Learning xss query param:(    <div id="js-repo-pjax-container" data-pjax-container>)
# ['<', 'div', 'id=', "''", 'js-repo-pjax-container', "''", 'data-pjax-container', '>']
# Learning xss query param:(      )
# []
# Learning xss query param:(  <div class="pagehead repohead instapaper_ignore readability-menu experiment-repo-nav ">)
# ['<', 'div', 'class=', "''", 'pagehead', 'repohead', 'instapaper_ignore', 'readability-menu', 'experiment-repo-nav', '``', '>']
# Learning xss query param:(    <div class="repohead-details-container clearfix container ">)
# ['<', 'div', 'class=', "''", 'repohead-details-container', 'clearfix', 'container', '``', '>']
# Learning xss query param:(      <ul class="pagehead-actions">)
# ['<', 'ul', 'class=', "''", 'pagehead-actions', "''", '>']
# Learning xss query param:(  <li>)
# ['<', 'li', '>']
# Learning xss query param:(        <!-- '"` --><!-- </textarea></xmp> --></option></form><form accept-charset="UTF-8" action="/notifications/subscribe" class="js-social-container" data-autosubmit="true" data-remote="true" method="post"><div style="margin:0;padding:0;display:inline"><input name="utf8" type="hidden" value="✓" /><input name="authenticity_token" type="hidden" value="yU1/0OYQA3exghPOJXyc2hjBhBh+c7W27LGNrBV+Ampe1/Qw4OM8Qpd9lc+s6yCMBBU751x5aiW5SKZ7KfgWEw==" /></div>      <input class="form-control" id="repository_id" name="repository_id" type="hidden" value="91390536" />)
# ['<', '!', '--', "'", "''", '`', '--', '>', '<', '!', '--', '<', '/textarea', '>', '<', '/xmp', '>', '--', '>', '<', '/option', '>', '<', '/form', '>', '<', 'form', 'accept-charset=', "''", 'UTF-8', "''", 'action=', "''", '/notifications/subscribe', "''", 'class=', "''", 'js-social-container', "''", 'data-autosubmit=', "''", 'true', "''", 'data-remote=', "''", 'true', "''", 'method=', "''", 'post', "''", '>', '<', 'div', 'style=', "''", 'margin:0', ';', 'padding:0', ';', 'display', ':', 'inline', "''", '>', '<', 'input', 'name=', "''", 'utf8', "''", 'type=', "''", 'hidden', "''", 'value=', "''", '✓', "''", '/', '>', '<', 'input', 'name=', "''", 'authenticity_token', "''", 'type=', "''", 'hidden', "''", 'value=', "''", 'yU1/0OYQA3exghPOJXyc2hjBhBh+c7W27LGNrBV+Ampe1/Qw4OM8Qpd9lc+s6yCMBBU751x5aiW5SKZ7KfgWEw==', "''", '/', '>', '<', '/div', '>', '<', 'input', 'class=', "''", 'form-control', "''", 'id=', "''", 'repository_id', "''", 'name=', "''", 'repository_id', "''", 'type=', "''", 'hidden', "''", 'value=', "''", '91390536', "''", '/', '>']
# Learning xss query param:(        <div class="select-menu js-menu-container js-select-menu">)
# ['<', 'div', 'class=', "''", 'select-menu', 'js-menu-container', 'js-select-menu', "''", '>']
# Learning xss query param:(          <a href="/duoergun0729/1book/subscription")
# ['<', 'a', 'href=', "''", '/duoergun0729/1book/subscription', "''"]
# Learning xss query param:(            class="btn btn-sm btn-with-count select-menu-button js-menu-target")
# ['class=', "''", 'btn', 'btn-sm', 'btn-with-count', 'select-menu-button', 'js-menu-target', "''"]
# Learning xss query param:(            role="button")
# ['role=', "''", 'button', "''"]
# Learning xss query param:(            aria-haspopup="true")
# ['aria-haspopup=', "''", 'true', "''"]
# Learning xss query param:(            aria-expanded="false")
# ['aria-expanded=', "''", 'false', "''"]
# Learning xss query param:(            aria-label="Toggle repository notifications menu")
# ['aria-label=', "''", 'Toggle', 'repository', 'notifications', 'menu', "''"]
# Learning xss query param:(            data-ga-click="Repository, click Watch settings, action:blob#show">)
# ['data-ga-click=', "''", 'Repository', ',', 'click', 'Watch', 'settings', ',', 'action', ':', 'blob', '#', 'show', "''", '>']
# Learning xss query param:(            <span class="js-select-button">)
# ['<', 'span', 'class=', "''", 'js-select-button', "''", '>']
# ...
# Learning xss query param:(</div>)
# ['<', '/div', '>']
# Learning xss query param:(    </div>)
# ['<', '/div', '>']
# Learning xss query param:(  </div>)
# ['<', '/div', '>']
# Learning xss query param:(  </div>)
# ['<', '/div', '>']
# Learning xss query param:(      )
# []
# Learning xss query param:(<div class="footer container-lg px-3" role="contentinfo">)
# ['<', 'div', 'class=', "''", 'footer', 'container-lg', 'px-3', "''", 'role=', "''", 'contentinfo', "''", '>']
# Learning xss query param:(  <div class="position-relative d-flex flex-justify-between py-6 mt-6 f6 text-gray border-top border-gray-light ">)
# ['<', 'div', 'class=', "''", 'position-relative', 'd-flex', 'flex-justify-between', 'py-6', 'mt-6', 'f6', 'text-gray', 'border-top', 'border-gray-light', '``', '>']
# Learning xss query param:(    <ul class="list-style-none d-flex flex-wrap ">)
# ['<', 'ul', 'class=', "''", 'list-style-none', 'd-flex', 'flex-wrap', '``', '>']
# Learning xss query param:(      <li class="mr-3">© 2017 <span title="0.23955s from unicorn-954199310-w5b23">GitHub</span>, Inc.</li>)
# ['<', 'li', 'class=', "''", 'mr-3', "''", '>', '©', '2017', '<', 'span', 'title=', "''", '0.23955s', 'from', 'unicorn-954199310-w5b23', "''", '>', 'GitHub', '<', '/span', '>', ',', 'Inc.', '<', '/li', '>']
# Learning xss query param:(        <li class="mr-3"><a href="https://github.com/site/terms" data-ga-click="Footer, go to terms, text:terms">Terms</a></li>)
# ['<', 'li', 'class=', "''", 'mr-3', "''", '>', '<', 'a', 'href=', "''", 'https', ':', '//github.com/site/terms', "''", 'data-ga-click=', "''", 'Footer', ',', 'go', 'to', 'terms', ',', 'text', ':', 'terms', "''", '>', 'Terms', '<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(        <li class="mr-3"><a href="https://github.com/site/privacy" data-ga-click="Footer, go to privacy, text:privacy">Privacy</a></li>)
# ['<', 'li', 'class=', "''", 'mr-3', "''", '>', '<', 'a', 'href=', "''", 'https', ':', '//github.com/site/privacy', "''", 'data-ga-click=', "''", 'Footer', ',', 'go', 'to', 'privacy', ',', 'text', ':', 'privacy', "''", '>', 'Privacy', '<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(        <li class="mr-3"><a href="https://github.com/security" data-ga-click="Footer, go to security, text:security">Security</a></li>)
# ['<', 'li', 'class=', "''", 'mr-3', "''", '>', '<', 'a', 'href=', "''", 'https', ':', '//github.com/security', "''", 'data-ga-click=', "''", 'Footer', ',', 'go', 'to', 'security', ',', 'text', ':', 'security', "''", '>', 'Security', '<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(        <li class="mr-3"><a href="https://status.github.com/" data-ga-click="Footer, go to status, text:status">Status</a></li>)
# ['<', 'li', 'class=', "''", 'mr-3', "''", '>', '<', 'a', 'href=', "''", 'https', ':', '//status.github.com/', "''", 'data-ga-click=', "''", 'Footer', ',', 'go', 'to', 'status', ',', 'text', ':', 'status', "''", '>', 'Status', '<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(        <li><a href="https://help.github.com" data-ga-click="Footer, go to help, text:help">Help</a></li>)
# ['<', 'li', '>', '<', 'a', 'href=', "''", 'https', ':', '//help.github.com', "''", 'data-ga-click=', "''", 'Footer', ',', 'go', 'to', 'help', ',', 'text', ':', 'help', "''", '>', 'Help', '<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(    </ul>)
# ['<', '/ul', '>']
# Learning xss query param:(    <a href="https://github.com" aria-label="Homepage" class="footer-octicon" title="GitHub">)
# ['<', 'a', 'href=', "''", 'https', ':', '//github.com', "''", 'aria-label=', "''", 'Homepage', "''", 'class=', "''", 'footer-octicon', "''", 'title=', "''", 'GitHub', "''", '>']
# Learning xss query param:(      <svg aria-hidden="true" class="octicon octicon-mark-github" height="24" version="1.1" viewBox="0 0 16 16" width="24"><path fill-rule="evenodd" d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0 0 16 8c0-4.42-3.58-8-8-8z"/></svg>)
# ['<', 'svg', 'aria-hidden=', "''", 'true', "''", 'class=', "''", 'octicon', 'octicon-mark-github', "''", 'height=', "''", '24', "''", 'version=', "''", '1.1', "''", 'viewBox=', "''", '0', '0', '16', '16', "''", 'width=', "''", '24', "''", '>', '<', 'path', 'fill-rule=', "''", 'evenodd', "''", 'd=', "''", 'M8', '0C3.58', '0', '0', '3.58', '0', '8c0', '3.54', '2.29', '6.53', '5.47', '7.59.4.07.55-.17.55-.38', '0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01', '1.08.58', '1.23.82.72', '1.21', '1.87.87', '2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95', '0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12', '0', '0', '.67-.21', '2.2.82.64-.18', '1.32-.27', '2-.27.68', '0', '1.36.09', '2', '.27', '1.53-1.04', '2.2-.82', '2.2-.82.44', '1.1.16', '1.92.08', '2.12.51.56.82', '1.27.82', '2.15', '0', '3.07-1.87', '3.75-3.65', '3.95.29.25.54.73.54', '1.48', '0', '1.07-.01', '1.93-.01', '2.2', '0', '.21.15.46.55.38A8.013', '8.013', '0', '0', '0', '16', '8c0-4.42-3.58-8-8-8z', "''", '/', '>', '<', '/svg', '>']
# Learning xss query param:(    <ul class="list-style-none d-flex flex-wrap ">)
# ['<', 'ul', 'class=', "''", 'list-style-none', 'd-flex', 'flex-wrap', '``', '>']
# Learning xss query param:(        <li class="mr-3"><a href="https://github.com/contact" data-ga-click="Footer, go to contact, text:contact">Contact GitHub</a></li>)
# ['<', 'li', 'class=', "''", 'mr-3', "''", '>', '<', 'a', 'href=', "''", 'https', ':', '//github.com/contact', "''", 'data-ga-click=', "''", 'Footer', ',', 'go', 'to', 'contact', ',', 'text', ':', 'contact', "''", '>', 'Contact', 'GitHub', '<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(      <li class="mr-3"><a href="https://developer.github.com" data-ga-click="Footer, go to api, text:api">API</a></li>)
# ['<', 'li', 'class=', "''", 'mr-3', "''", '>', '<', 'a', 'href=', "''", 'https', ':', '//developer.github.com', "''", 'data-ga-click=', "''", 'Footer', ',', 'go', 'to', 'api', ',', 'text', ':', 'api', "''", '>', 'API', '<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(      <li class="mr-3"><a href="https://training.github.com" data-ga-click="Footer, go to training, text:training">Training</a></li>)
# ['<', 'li', 'class=', "''", 'mr-3', "''", '>', '<', 'a', 'href=', "''", 'https', ':', '//training.github.com', "''", 'data-ga-click=', "''", 'Footer', ',', 'go', 'to', 'training', ',', 'text', ':', 'training', "''", '>', 'Training', '<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(      <li class="mr-3"><a href="https://shop.github.com" data-ga-click="Footer, go to shop, text:shop">Shop</a></li>)
# ['<', 'li', 'class=', "''", 'mr-3', "''", '>', '<', 'a', 'href=', "''", 'https', ':', '//shop.github.com', "''", 'data-ga-click=', "''", 'Footer', ',', 'go', 'to', 'shop', ',', 'text', ':', 'shop', "''", '>', 'Shop', '<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(        <li class="mr-3"><a href="https://github.com/blog" data-ga-click="Footer, go to blog, text:blog">Blog</a></li>)
# ['<', 'li', 'class=', "''", 'mr-3', "''", '>', '<', 'a', 'href=', "''", 'https', ':', '//github.com/blog', "''", 'data-ga-click=', "''", 'Footer', ',', 'go', 'to', 'blog', ',', 'text', ':', 'blog', "''", '>', 'Blog', '<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(        <li><a href="https://github.com/about" data-ga-click="Footer, go to about, text:about">About</a></li>)
# ['<', 'li', '>', '<', 'a', 'href=', "''", 'https', ':', '//github.com/about', "''", 'data-ga-click=', "''", 'Footer', ',', 'go', 'to', 'about', ',', 'text', ':', 'about', "''", '>', 'About', '<', '/a', '>', '<', '/li', '>']
# Learning xss query param:(    </ul>)
# ['<', '/ul', '>']
# Learning xss query param:(  </div>)
# ['<', '/div', '>']
# Learning xss query param:(</div>)
# ['<', '/div', '>']
# Learning xss query param:(  <div id="ajax-error-message" class="ajax-error-message flash flash-error">)
# ['<', 'div', 'id=', "''", 'ajax-error-message', "''", 'class=', "''", 'ajax-error-message', 'flash', 'flash-error', "''", '>']
# Learning xss query param:(    <svg aria-hidden="true" class="octicon octicon-alert" height="16" version="1.1" viewBox="0 0 16 16" width="16"><path fill-rule="evenodd" d="M8.865 1.52c-.18-.31-.51-.5-.87-.5s-.69.19-.87.5L.275 13.5c-.18.31-.18.69 0 1 .19.31.52.5.87.5h13.7c.36 0 .69-.19.86-.5.17-.31.18-.69.01-1L8.865 1.52zM8.995 13h-2v-2h2v2zm0-3h-2V6h2v4z"/></svg>)
# ['<', 'svg', 'aria-hidden=', "''", 'true', "''", 'class=', "''", 'octicon', 'octicon-alert', "''", 'height=', "''", '16', "''", 'version=', "''", '1.1', "''", 'viewBox=', "''", '0', '0', '16', '16', "''", 'width=', "''", '16', "''", '>', '<', 'path', 'fill-rule=', "''", 'evenodd', "''", 'd=', "''", 'M8.865', '1.52c-.18-.31-.51-.5-.87-.5s-.69.19-.87.5L.275', '13.5c-.18.31-.18.69', '0', '1', '.19.31.52.5.87.5h13.7c.36', '0', '.69-.19.86-.5.17-.31.18-.69.01-1L8.865', '1.52zM8.995', '13h-2v-2h2v2zm0-3h-2V6h2v4z', "''", '/', '>', '<', '/svg', '>']
# Learning xss query param:(    <button type="button" class="flash-close js-ajax-error-dismiss" aria-label="Dismiss error">)
# ['<', 'button', 'type=', "''", 'button', "''", 'class=', "''", 'flash-close', 'js-ajax-error-dismiss', "''", 'aria-label=', "''", 'Dismiss', 'error', "''", '>']
# Learning xss query param:(      <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewBox="0 0 12 16" width="12"><path fill-rule="evenodd" d="M7.48 8l3.75 3.75-1.48 1.48L6 9.48l-3.75 3.75-1.48-1.48L4.52 8 .77 4.25l1.48-1.48L6 6.52l3.75-3.75 1.48 1.48z"/></svg>)
# ['<', 'svg', 'aria-hidden=', "''", 'true', "''", 'class=', "''", 'octicon', 'octicon-x', "''", 'height=', "''", '16', "''", 'version=', "''", '1.1', "''", 'viewBox=', "''", '0', '0', '12', '16', "''", 'width=', "''", '12', "''", '>', '<', 'path', 'fill-rule=', "''", 'evenodd', "''", 'd=', "''", 'M7.48', '8l3.75', '3.75-1.48', '1.48L6', '9.48l-3.75', '3.75-1.48-1.48L4.52', '8', '.77', '4.25l1.48-1.48L6', '6.52l3.75-3.75', '1.48', '1.48z', "''", '/', '>', '<', '/svg', '>']
# Learning xss query param:(    </button>)
# ['<', '/button', '>']
# Learning xss query param:(    You can't perform that action at this time.)
# ['You', 'ca', "n't", 'perform', 'that', 'action', 'at', 'this', 'time', '.']
# Learning xss query param:(  </div>)
# ['<', '/div', '>']
# Learning xss query param:(    <script crossorigin="anonymous" integrity="sha256-R7c3eUp64zkx0aUKgHD8RyBMQTxCRYqXgUMLHeA4450=" src="https://assets-cdn.github.com/assets/frameworks-47b737794a7ae33931d1a50a8070fc47204c413c42458a9781430b1de038e39d.js"></script>)
# ['<', 'script', 'crossorigin=', "''", 'anonymous', "''", 'integrity=', "''", 'sha256-R7c3eUp64zkx0aUKgHD8RyBMQTxCRYqXgUMLHeA4450=', "''", 'src=', "''", 'https', ':', '//assets-cdn.github.com/assets/frameworks-47b737794a7ae33931d1a50a8070fc47204c413c42458a9781430b1de038e39d.js', "''", '>', '<', '/script', '>']
# Learning xss query param:(    <script async="async" crossorigin="anonymous" integrity="sha256-Qkc87DGR10XKre61lV2syUoYE2acFhpZ4zg4WtwcvJA=" src="https://assets-cdn.github.com/assets/github-42473cec3191d745caadeeb5955dacc94a1813669c161a59e338385adc1cbc90.js"></script>)
# ['<', 'script', 'async=', "''", 'async', "''", 'crossorigin=', "''", 'anonymous', "''", 'integrity=', "''", 'sha256-Qkc87DGR10XKre61lV2syUoYE2acFhpZ4zg4WtwcvJA=', "''", 'src=', "''", 'https', ':', '//assets-cdn.github.com/assets/github-42473cec3191d745caadeeb5955dacc94a1813669c161a59e338385adc1cbc90.js', "''", '>', '<', '/script', '>']
# Learning xss query param:(  <div class="js-stale-session-flash stale-session-flash flash flash-warn flash-banner d-none">)
# ['<', 'div', 'class=', "''", 'js-stale-session-flash', 'stale-session-flash', 'flash', 'flash-warn', 'flash-banner', 'd-none', "''", '>']
# Learning xss query param:(    <svg aria-hidden="true" class="octicon octicon-alert" height="16" version="1.1" viewBox="0 0 16 16" width="16"><path fill-rule="evenodd" d="M8.865 1.52c-.18-.31-.51-.5-.87-.5s-.69.19-.87.5L.275 13.5c-.18.31-.18.69 0 1 .19.31.52.5.87.5h13.7c.36 0 .69-.19.86-.5.17-.31.18-.69.01-1L8.865 1.52zM8.995 13h-2v-2h2v2zm0-3h-2V6h2v4z"/></svg>)
# ['<', 'svg', 'aria-hidden=', "''", 'true', "''", 'class=', "''", 'octicon', 'octicon-alert', "''", 'height=', "''", '16', "''", 'version=', "''", '1.1', "''", 'viewBox=', "''", '0', '0', '16', '16', "''", 'width=', "''", '16', "''", '>', '<', 'path', 'fill-rule=', "''", 'evenodd', "''", 'd=', "''", 'M8.865', '1.52c-.18-.31-.51-.5-.87-.5s-.69.19-.87.5L.275', '13.5c-.18.31-.18.69', '0', '1', '.19.31.52.5.87.5h13.7c.36', '0', '.69-.19.86-.5.17-.31.18-.69.01-1L8.865', '1.52zM8.995', '13h-2v-2h2v2zm0-3h-2V6h2v4z', "''", '/', '>', '<', '/svg', '>']
# Learning xss query param:(    <span class="signed-in-tab-flash">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>)
# ['<', 'span', 'class=', "''", 'signed-in-tab-flash', "''", '>', 'You', 'signed', 'in', 'with', 'another', 'tab', 'or', 'window', '.', '<', 'a', 'href=', "''", "''", '>', 'Reload', '<', '/a', '>', 'to', 'refresh', 'your', 'session.', '<', '/span', '>']
# Learning xss query param:(    <span class="signed-out-tab-flash">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>)
# ['<', 'span', 'class=', "''", 'signed-out-tab-flash', "''", '>', 'You', 'signed', 'out', 'in', 'another', 'tab', 'or', 'window', '.', '<', 'a', 'href=', "''", "''", '>', 'Reload', '<', '/a', '>', 'to', 'refresh', 'your', 'session.', '<', '/span', '>']
# Learning xss query param:(  </div>)
# ['<', '/div', '>']
# Learning xss query param:(  <div class="facebox" id="facebox" style="display:none;">)
# ['<', 'div', 'class=', "''", 'facebox', "''", 'id=', "''", 'facebox', "''", 'style=', "''", 'display', ':', 'none', ';', "''", '>']
# Learning xss query param:(  <div class="facebox-popup">)
# ['<', 'div', 'class=', "''", 'facebox-popup', "''", '>']
# Learning xss query param:(    <div class="facebox-content" role="dialog" aria-labelledby="facebox-header" aria-describedby="facebox-description">)
# ['<', 'div', 'class=', "''", 'facebox-content', "''", 'role=', "''", 'dialog', "''", 'aria-labelledby=', "''", 'facebox-header', "''", 'aria-describedby=', "''", 'facebox-description', "''", '>']
# Learning xss query param:(    </div>)
# ['<', '/div', '>']
# Learning xss query param:(    <button type="button" class="facebox-close js-facebox-close" aria-label="Close modal">)
# ['<', 'button', 'type=', "''", 'button', "''", 'class=', "''", 'facebox-close', 'js-facebox-close', "''", 'aria-label=', "''", 'Close', 'modal', "''", '>']
# Learning xss query param:(      <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewBox="0 0 12 16" width="12"><path fill-rule="evenodd" d="M7.48 8l3.75 3.75-1.48 1.48L6 9.48l-3.75 3.75-1.48-1.48L4.52 8 .77 4.25l1.48-1.48L6 6.52l3.75-3.75 1.48 1.48z"/></svg>)
# ['<', 'svg', 'aria-hidden=', "''", 'true', "''", 'class=', "''", 'octicon', 'octicon-x', "''", 'height=', "''", '16', "''", 'version=', "''", '1.1', "''", 'viewBox=', "''", '0', '0', '12', '16', "''", 'width=', "''", '12', "''", '>', '<', 'path', 'fill-rule=', "''", 'evenodd', "''", 'd=', "''", 'M7.48', '8l3.75', '3.75-1.48', '1.48L6', '9.48l-3.75', '3.75-1.48-1.48L4.52', '8', '.77', '4.25l1.48-1.48L6', '6.52l3.75-3.75', '1.48', '1.48z', "''", '/', '>', '<', '/svg', '>']
# Learning xss query param:(    </button>)
# ['<', '/button', '>']
# Learning xss query param:(  </div>)
# ['<', '/div', '>']
# Learning xss query param:(</div>)
# ['<', '/div', '>']
# Learning xss query param:(  </body>)
# ['<', '/body', '>']
# Learning xss query param:(</html>)
# ['<', '/html', '>']
