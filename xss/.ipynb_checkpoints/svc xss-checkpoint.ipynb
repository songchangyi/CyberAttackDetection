# %%
import re
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

def get_len(info_comp):
    return len(info_comp)

def get_evil_char(info_comp):
    return len(re.findall("[<>\"\'=&{}!#\*]", info_comp, re.IGNORECASE))

def get_evil_word(info_comp):
    return len(re.findall("(alert)|(script)|(XSS)|(SRC=)|(xss)|(onerror)|(onload)|(BODY)|(src=)|(INPUT)|(http)|(LINK)|(url=)|(SCRIPT)",info_comp,re.IGNORECASE))

def get_feature(info_comp):
    return [get_len(info_comp),get_evil_char(info_comp),get_evil_word(info_comp)]

# %%
import pandas as pd #数据分析
import numpy as np #科学计算
from pandas import Series,DataFrame
data_logs = pd.read_csv("logxss1.csv",encoding = 'latin1')
data_logs
# Out:
#       Unnamed: 0              ip         date  hour  minute  seconds  zone  \
# 0              1  192.108.116.88  18/Dec/2017    13       0       31     0
# 1              2  192.108.116.88  18/Dec/2017    13       0       31     0
# 2              3  192.108.116.88  18/Dec/2017    13       0       31     0
# 3              4  192.108.116.88  18/Dec/2017    13       2       31     0
# 4              5  192.108.116.88  18/Dec/2017    13       4       31     0
# 5              6  192.108.116.88  18/Dec/2017    13       4       56     0
# 6              7  192.108.116.88  18/Dec/2017    13       4       56     0
# 7              8  192.108.116.88  18/Dec/2017    13       4       56     0
# 8              9  192.108.116.88  18/Dec/2017    13       4       57     0
# 9             10  192.108.116.88  18/Dec/2017    13       4       57     0
# 10            11  192.108.116.88  18/Dec/2017    13       4       57     0
# 11            12  192.108.116.88  18/Dec/2017    13       5       16     0
# 12            13  192.108.116.88  18/Dec/2017    13       5       16     0
# 13            14  192.108.116.88  18/Dec/2017    13       5       16     0
# 14            15  192.108.116.88  18/Dec/2017    13       5       16     0
# 15            16  192.108.116.88  18/Dec/2017    13       5       16     0
# 16            17  192.108.116.88  18/Dec/2017    13       5       16     0
# 17            18  192.108.116.88  18/Dec/2017    13       5       38     0
# 18            19  192.108.116.88  18/Dec/2017    13       5       38     0
# 19            20  192.108.116.88  18/Dec/2017    13       5       38     0
# 20            21  192.108.116.88  18/Dec/2017    13       5       39     0
# 21            22  192.108.116.88  18/Dec/2017    13       5       39     0
# 22            23  192.108.116.88  18/Dec/2017    13       5       39     0
# 23            24  192.108.116.88  18/Dec/2017    13       6        3     0
# 24            25  192.108.116.88  18/Dec/2017    13       6        3     0
# 25            26  192.108.116.88  18/Dec/2017    13       6        3     0
# 26            27  192.108.116.88  18/Dec/2017    13       6        3     0
# 27            28  192.108.116.88  18/Dec/2017    13       6        4     0
# 28            29  192.108.116.88  18/Dec/2017    13       6        4     0
# 29            30  192.108.116.88  18/Dec/2017    13       6       26     0
# ...          ...             ...          ...   ...     ...      ...   ...
# 1489        1490  192.108.116.88  15/Dec/2017    15      42       13     0
# 1490        1491  192.108.116.88  15/Dec/2017    15      42       13     0
# 1491        1492  192.108.116.88  15/Dec/2017    15      42       13     0
# 1492        1493  192.108.116.88  15/Dec/2017    15      42       13     0
# 1493        1494  192.108.116.88  15/Dec/2017    15      42       13     0
# 1494        1495  192.108.116.88  15/Dec/2017    15      42       13     0
# 1495        1496  192.108.116.88  15/Dec/2017    15      42       15     0
# 1496        1497  192.108.116.88  15/Dec/2017    15      42       15     0
# 1497        1498  192.108.116.88  15/Dec/2017    15      42       15     0
# 1498        1499  192.108.116.88  15/Dec/2017    15      42       16     0
# 1499        1500  192.108.116.88  15/Dec/2017    15      42       16     0
# 1500        1501  192.108.116.88  15/Dec/2017    15      42       16     0
# 1501        1502  192.108.116.88  15/Dec/2017    15      42       16     0
# 1502        1503  192.108.116.88  15/Dec/2017    15      42       16     0
# 1503        1504  192.108.116.88  15/Dec/2017    15      42       16     0
# 1504        1505  192.108.116.88  15/Dec/2017    15      42       18     0
# 1505        1506  192.108.116.88  15/Dec/2017    15      42       18     0
# 1506        1507  192.108.116.88  15/Dec/2017    15      42       18     0
# 1507        1508  192.108.116.88  15/Dec/2017    15      42       19     0
# 1508        1509  192.108.116.88  15/Dec/2017    15      42       19     0
# 1509        1510  192.108.116.88  15/Dec/2017    15      42       19     0
# 1510        1511  192.108.116.88  15/Dec/2017    15      42       19     0
# 1511        1512  192.108.116.88  15/Dec/2017    15      42       19     0
# 1512        1513  192.108.116.88  15/Dec/2017    15      42       19     0
# 1513        1514  192.108.116.88  15/Dec/2017    15      42       22     0
# 1514        1515  192.108.116.88  15/Dec/2017    15      42       22     0
# 1515        1516  192.108.116.88  15/Dec/2017    15      42       22     0
# 1516        1517  192.108.116.88  15/Dec/2017    15      42       22     0
# 1517        1518  192.108.116.88  15/Dec/2017    15      42       22     0
# 1518        1519  192.108.116.88  15/Dec/2017    15      42       22     0
#
#      request1                                           request2  status  \
# 0        GET    HTTP/1.1/NA/datalab ';alert(String.fromCharCo...   200.0
# 1        GET   css/index.css HTTP/1.1/datalab ';alert(String....   200.0
# 2        GET   img/logo.png HTTP/1.1/datalab ';alert(String.f...   200.0
# 3       POST   datalab HTTP/1.1/NA/datalab ';alert(String.fro...     NaN
# 4       POST   datalab HTTP/1.1/NA/datalab ';alert(String.fro...     NaN
# 5        GET             HTTP/1.1/NA/datalab '';!--"<XSS>=&{()}    200.0
# 6        GET   css/index.css HTTP/1.1/datalab '';!--"<XSS>=&{...   200.0
# 7        GET   img/logo.png HTTP/1.1/datalab '';!--"<XSS>=&{()}    200.0
# 8       POST     datalab HTTP/1.1/NA/datalab '';!--"<XSS>=&{()}    200.0
# 9        GET   css/index.css HTTP/1.1/datalab '';!--"<XSS>=&{...   304.0
# 10       GET   img/logo.png HTTP/1.1/datalab '';!--"<XSS>=&{()}    304.0
# 11       GET    HTTP/1.1/NA/datalab 0\"autofocus/onfocus=aler...   200.0
# 12       GET   css/index.css HTTP/1.1/datalab 0\"autofocus/on...   200.0
# 13       GET   img/logo.png HTTP/1.1/datalab 0\"autofocus/onf...   200.0
# 14      POST   datalab HTTP/1.1/NA/datalab 0\"autofocus/onfoc...   200.0
# 15       GET   img/logo.png HTTP/1.1/datalab 0\"autofocus/onf...   304.0
# 16       GET   css/index.css HTTP/1.1/datalab 0\"autofocus/on...   304.0
# 17       GET     HTTP/1.1/NA/datalab <script/src=data:,alert()>    200.0
# 18       GET   css/index.css HTTP/1.1/datalab <script/src=dat...   200.0
# 19       GET   img/logo.png HTTP/1.1/datalab <script/src=data...   200.0
# 20      POST   datalab HTTP/1.1/NA/datalab <script/src=data:,...   200.0
# 21       GET   css/index.css HTTP/1.1/datalab <script/src=dat...   304.0
# 22       GET   img/logo.png HTTP/1.1/datalab <script/src=data...   304.0
# 23       GET      HTTP/1.1/NA/datalab <marquee/onstart=alert()>    200.0
# 24       GET   css/index.css HTTP/1.1/datalab <marquee/onstar...   200.0
# 25       GET   img/logo.png HTTP/1.1/datalab <marquee/onstart...   200.0
# 26      POST   datalab HTTP/1.1/NA/datalab <marquee/onstart=a...   200.0
# 27       GET   css/index.css HTTP/1.1/datalab <marquee/onstar...   304.0
# 28       GET   img/logo.png HTTP/1.1/datalab <marquee/onstart...   304.0
# 29       GET    HTTP/1.1/NA/datalab <video/poster/onerror=ale...   200.0
# ...       ...                                                ...     ...
# 1489    POST                                datalab HTTP/1.1/NA/   200.0
# 1490     GET                             css/index.css HTTP/1.1/   304.0
# 1491     GET                              img/logo.png HTTP/1.1/   304.0
# 1492    POST                                datalab HTTP/1.1/NA/   200.0
# 1493     GET                             css/index.css HTTP/1.1/   304.0
# 1494     GET                              img/logo.png HTTP/1.1/   304.0
# 1495     GET                                        HTTP/1.1/NA/   304.0
# 1496     GET                             css/index.css HTTP/1.1/   304.0
# 1497     GET                              img/logo.png HTTP/1.1/   304.0
# 1498    POST                                datalab HTTP/1.1/NA/   200.0
# 1499     GET                             css/index.css HTTP/1.1/   304.0
# 1500     GET                              img/logo.png HTTP/1.1/   304.0
# 1501    POST                                datalab HTTP/1.1/NA/   200.0
# 1502     GET                             css/index.css HTTP/1.1/   304.0
# 1503     GET                              img/logo.png HTTP/1.1/   304.0
# 1504     GET                                        HTTP/1.1/NA/   304.0
# 1505     GET                             css/index.css HTTP/1.1/   304.0
# 1506     GET                              img/logo.png HTTP/1.1/   304.0
# 1507    POST                                datalab HTTP/1.1/NA/   200.0
# 1508     GET                             css/index.css HTTP/1.1/   304.0
# 1509     GET                              img/logo.png HTTP/1.1/   304.0
# 1510    POST                                datalab HTTP/1.1/NA/   200.0
# 1511     GET                             css/index.css HTTP/1.1/   304.0
# 1512     GET                              img/logo.png HTTP/1.1/   304.0
# 1513     GET                                        HTTP/1.1/NA/   304.0
# 1514     GET                             css/index.css HTTP/1.1/   304.0
# 1515     GET                              img/logo.png HTTP/1.1/   304.0
# 1516    POST                                datalab HTTP/1.1/NA/   200.0
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        1
# 11                                          Mozilla/5.0        1
# 12                                          Mozilla/5.0        1
# 13                                          Mozilla/5.0        1
# 14                                          Mozilla/5.0        1
# 15                                          Mozilla/5.0        1
# 16                                          Mozilla/5.0        1
# 17    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        1
# 18    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        1
# 19    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        1
# 20    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        1
# 21    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        1
# 22    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        1
# 23    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        1
# 24    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        1
# 25    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        1
# 26    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        1
# 27    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        1
# 28    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        1
# 29    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        1
# ...                                                 ...      ...
# 1489  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1490  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1491  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1492  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1493  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1494  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1495  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1496  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1497  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1498  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1499  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1500  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1501  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1502  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1503  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1504  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1505  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1506  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1507  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1508  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1509  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1510  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1511  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1512  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1513  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1514  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1515  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1516  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1517  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
# 1518  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...        0
#
# [1519 rows x 14 columns]

# %%
x=[]
for line in data_logs.request2.values:
    f1=get_len(line)
    f2=get_evil_char(line)
    f3=get_evil_word(line)
    x.append([f1,f2,f3])
print(x)
# Out:
# [[251, 15, 9], [261, 15, 9], [260, 15, 9], [258, 15, 9], [258, 15, 9], [40, 10, 2], [50, 10, 2], [49, 10, 2], [47, 10, 2], [50, 10, 2], [49, 10, 2], [99, 7, 3], [109, 7, 3], [108, 7, 3], [106, 7, 3], [108, 7, 3], [109, 7, 3], [48, 3, 4], [58, 3, 4], [57, 3, 4], [55, 3, 4], [58, 3, 4], [57, 3, 4], [47, 3, 2], [57, 3, 2], [56, 3, 2], [54, 3, 2], [57, 3, 2], [56, 3, 2], [52, 3, 3], [62, 3, 3], [61, 3, 3], [59, 3, 3], [62, 3, 3], [61, 3, 3], [57, 3, 2], [67, 3, 2], [66, 3, 2], [64, 3, 2], [66, 3, 2], [67, 3, 2], [70, 5, 6], [80, 5, 6], [79, 5, 6], [77, 5, 6], [80, 5, 6], [79, 5, 6], [58, 7, 5], [68, 7, 5], [67, 7, 5], [65, 7, 5], [65, 7, 5], [55, 5, 5], [65, 5, 5], [64, 5, 5], [62, 5, 5], [62, 5, 5], [58, 7, 5], [68, 7, 5], [67, 7, 5], [65, 7, 5], [65, 7, 5], [55, 5, 5], [65, 5, 5], [64, 5, 5], [62, 5, 5], [62, 5, 5], [55, 5, 5], [65, 5, 5], [64, 5, 5], [62, 5, 5], [62, 5, 5], [55, 5, 5], [65, 5, 5], [64, 5, 5], [62, 5, 5], [65, 5, 5], [64, 5, 5], [72, 7, 5], [82, 7, 5], [81, 7, 5], [79, 7, 5], [79, 7, 5], [74, 7, 3], [84, 7, 3], [83, 7, 3], [81, 7, 3], [84, 7, 3], [83, 7, 3], [72, 5, 3], [82, 5, 3], [81, 5, 3], [79, 5, 3], [82, 5, 3], [81, 5, 3], [62, 13, 5], [72, 13, 5], [71, 13, 5], [69, 13, 5], [72, 13, 5], [71, 13, 5], [79, 3, 4], [89, 3, 4], [88, 3, 4], [86, 3, 4], [89, 3, 4], [88, 3, 4], [60, 9, 3], [70, 9, 3], [69, 9, 3], [67, 9, 3], [67, 9, 3], [59, 8, 3], [69, 8, 3], [68, 8, 3], [66, 8,
, 4], [51, 5, 3], [61, 5, 3], [60, 5, 3], [58, 5, 3], [61, 5, 3], [60, 5, 3], [48, 5, 5], [58, 5, 5], [57, 5, 5], [55, 5, 5], [55, 5, 5], [62, 7, 5], [72, 7, 5], [71, 7, 5], [69, 7, 5], [69, 7, 5], [49, 10, 3], [59, 10, 3], [58, 10, 3], [56, 10, 3], [56, 10, 3], [75, 9, 5], [85, 9, 5], [84, 9, 5], [82, 9, 5], [82, 9, 5], [78, 7, 4], [88, 7, 4], [87, 7, 4], [85, 7, 4], [88, 7, 4], [87, 7, 4], [74, 6, 3], [84, 6, 3], [83, 6, 3], [81, 6, 3], [81, 6, 3], [78, 7, 4], [88, 7, 4], [87, 7, 4], [85, 7, 4], [88, 7, 4], [87, 7, 4], [74, 6, 3], [84, 6, 3], [83, 6, 3], [81, 6, 3], [81, 6, 3], [83 ...

# %%
y=data_logs.attaque.values
print(y)
# Out:
# [1 1 1 ..., 0 0 0]

# %%
from sklearn import metrics
def do_metrics(y_test,y_pred):
    print ("metrics.accuracy_score:")
    print (metrics.accuracy_score(y_test, y_pred))
    print ("metrics.confusion_matrix:")
    print (metrics.confusion_matrix(y_test, y_pred))
    print ("metrics.precision_score:")
    print (metrics.precision_score(y_test, y_pred))
    print ("metrics.recall_score:")
    print (metrics.recall_score(y_test, y_pred))
    print ("metrics.f1_score:")
    print (metrics.f1_score(y_test,y_pred))

# %%
from sklearn import cross_validation
from sklearn import datasets
from sklearn import svm
from sklearn.externals import  joblib
import matplotlib.pyplot as plt
x_train, x_test, y_train, y_test = cross_validation.train_test_split(x,y, test_size=0.4, random_state=0)
clf = svm.SVC(kernel='linear', C=1).fit(x_train, y_train)
y_pred = clf.predict(x_test)
do_metrics(y_test, y_pred)
# Out:
# metrics.accuracy_score:
# 1.0
# metrics.confusion_matrix:
# [[359   0]
#  [  0 249]]
# metrics.precision_score:
# 1.0
# metrics.recall_score:
# 1.0
# metrics.f1_score:
# 1.0

# %%
labels = ['attaque', 'no attaque']
cm = metrics.confusion_matrix(y_test, y_pred)

def plot_cm(cm, labels):
    
    # Compute percentanges
    percent = (cm*100.0)/np.array(np.matrix(cm.sum(axis=1)).T)  # Derp, I'm sure there's a better way
    
    print ('Confusion Matrix Stats')
    for i, label_i in enumerate(labels):
        for j, label_j in enumerate(labels):
            print ("%s/%s: %.2f%% (%d/%d)" % (label_i, label_j, (percent[i][j]), cm[i][j], cm[i].sum()))

    # Show confusion matrix
    # Thanks kermit666 from stackoverflow :)
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.grid(b=False)
    cax = ax.matshow(percent, cmap='coolwarm')
    plt.title('Confusion matrix of the classifier')
    fig.colorbar(cax)
    ax.set_xticklabels([''] + labels)
    ax.set_yticklabels([''] + labels)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

plot_cm(cm, labels)
# Out:
# Confusion Matrix Stats
# attaque/attaque: 100.00% (359/359)
# attaque/no attaque: 0.00% (0/359)
# no attaque/attaque: 0.00% (0/249)
# no attaque/no attaque: 100.00% (249/249)
