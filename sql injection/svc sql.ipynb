# %%
import re
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

def get_len(info_comp):
    return len(info_comp)

def get_evil_char(info_comp):
    return len(re.findall("[?=\*#@%>]", info_comp, re.IGNORECASE))

def get_evil_word(info_comp):
    return len(re.findall("(SELECT)|(version)|(comment)|(user)|(FROM)|(mysql)|(host)|(DELET)|(name)|(MYSQL)|(WHERE)|(password)|(ORDER)",info_comp,re.IGNORECASE))

def get_feature(info_comp):
    return [get_len(info_comp),get_evil_char(info_comp),get_evil_word(info_comp)]

# %%
import pandas as pd #数据分析
import numpy as np #科学计算
from pandas import Series,DataFrame
data_logs = pd.read_csv("logsql.csv")
data_logs
# Out:
#       Unnamed: 0              ip         date  hour  minute  seconds  zone  \
# 0              1  192.108.116.88  17/Dec/2017    16      19       59     0
# 1              2  192.108.116.88  17/Dec/2017    16      19       59     0
# 2              3  192.108.116.88  17/Dec/2017    16      19       59     0
# 3              4  192.108.116.88  17/Dec/2017    16      20        0     0
# 4              5  192.108.116.88  17/Dec/2017    16      20        0     0
# 5              6  192.108.116.88  17/Dec/2017    16      20        0     0
# 6              7  192.108.116.88  17/Dec/2017    16      20       22     0
# 7              8  192.108.116.88  17/Dec/2017    16      20       22     0
# 8              9  192.108.116.88  17/Dec/2017    16      20       22     0
# 9             10  192.108.116.88  17/Dec/2017    16      20       23     0
# 10            11  192.108.116.88  17/Dec/2017    16      20       24     0
# 11            12  192.108.116.88  17/Dec/2017    16      20       24     0
# 12            13  192.108.116.88  17/Dec/2017    16      20       40     0
# 13            14  192.108.116.88  17/Dec/2017    16      20       40     0
# 14            15  192.108.116.88  17/Dec/2017    16      20       40     0
# 15            16  192.108.116.88  17/Dec/2017    16      20       41     0
# 16            17  192.108.116.88  17/Dec/2017    16      20       41     0
# 17            18  192.108.116.88  17/Dec/2017    16      20       41     0
# 18            19  192.108.116.88  17/Dec/2017    16      20       58     0
# 19            20  192.108.116.88  17/Dec/2017    16      20       59     0
# 20            21  192.108.116.88  17/Dec/2017    16      20       59     0
# 21            22  192.108.116.88  17/Dec/2017    16      21        0     0
# 22            23  192.108.116.88  17/Dec/2017    16      21        0     0
# 23            24  192.108.116.88  17/Dec/2017    16      21        0     0
# 24            25  192.108.116.88  17/Dec/2017    16      21       17     0
# 25            26  192.108.116.88  17/Dec/2017    16      21       17     0
# 26            27  192.108.116.88  17/Dec/2017    16      21       17     0
# 27            28  192.108.116.88  17/Dec/2017    16      21       19     0
# 28            29  192.108.116.88  17/Dec/2017    16      21       19     0
# 29            30  192.108.116.88  17/Dec/2017    16      21       19     0
# ...          ...             ...          ...   ...     ...      ...   ...
# 1116        1117  192.108.116.88  15/Dec/2017    15      42       13     0
# 1117        1118  192.108.116.88  15/Dec/2017    15      42       13     0
# 1118        1119  192.108.116.88  15/Dec/2017    15      42       13     0
# 1119        1120  192.108.116.88  15/Dec/2017    15      42       13     0
# 1120        1121  192.108.116.88  15/Dec/2017    15      42       13     0
# 1121        1122  192.108.116.88  15/Dec/2017    15      42       13     0
# 1122        1123  192.108.116.88  15/Dec/2017    15      42       15     0
# 1123        1124  192.108.116.88  15/Dec/2017    15      42       15     0
# 1124        1125  192.108.116.88  15/Dec/2017    15      42       15     0
# 1125        1126  192.108.116.88  15/Dec/2017    15      42       16     0
# 1126        1127  192.108.116.88  15/Dec/2017    15      42       16     0
# 1127        1128  192.108.116.88  15/Dec/2017    15      42       16     0
# 1128        1129  192.108.116.88  15/Dec/2017    15      42       16     0
# 1129        1130  192.108.116.88  15/Dec/2017    15      42       16     0
# 1130        1131  192.108.116.88  15/Dec/2017    15      42       16     0
# 1131        1132  192.108.116.88  15/Dec/2017    15      42       18     0
# 1132        1133  192.108.116.88  15/Dec/2017    15      42       18     0
# 1133        1134  192.108.116.88  15/Dec/2017    15      42       18     0
# 1134        1135  192.108.116.88  15/Dec/2017    15      42       19     0
# 1135        1136  192.108.116.88  15/Dec/2017    15      42       19     0
# 1136        1137  192.108.116.88  15/Dec/2017    15      42       19     0
# 1137        1138  192.108.116.88  15/Dec/2017    15      42       19     0
# 1138        1139  192.108.116.88  15/Dec/2017    15      42       19     0
# 1139        1140  192.108.116.88  15/Dec/2017    15      42       19     0
# 1140        1141  192.108.116.88  15/Dec/2017    15      42       22     0
# 1141        1142  192.108.116.88  15/Dec/2017    15      42       22     0
# 1142        1143  192.108.116.88  15/Dec/2017    15      42       22     0
# 1143        1144  192.108.116.88  15/Dec/2017    15      42       22     0
# 1144        1145  192.108.116.88  15/Dec/2017    15      42       22     0
# 1145        1146  192.108.116.88  15/Dec/2017    15      42       22     0
#
#      request1                request2  status  respsize  \
# 0        GET              HTTP/1.1/NA   200.0    1040.0
# 1        GET   css/index.css HTTP/1.1   200.0     945.0
# 2        GET    img/logo.png HTTP/1.1   200.0   34463.0
# 3       POST      datalab HTTP/1.1/NA   200.0    1073.0
# 4        GET   css/index.css HTTP/1.1   304.0       NaN
# 5        GET    img/logo.png HTTP/1.1   304.0       NaN
# 6        GET              HTTP/1.1/NA   200.0    1040.0
# 7        GET   css/index.css HTTP/1.1   200.0     945.0
# 8        GET    img/logo.png HTTP/1.1   200.0   34463.0
# 9       POST      datalab HTTP/1.1/NA   200.0    1073.0
# 10       GET   css/index.css HTTP/1.1   304.0       NaN
# 11       GET    img/logo.png HTTP/1.1   304.0       NaN
# 12       GET              HTTP/1.1/NA   200.0    1040.0
# 13       GET   css/index.css HTTP/1.1   200.0     945.0
# 14       GET    img/logo.png HTTP/1.1   200.0   34463.0
# 15      POST      datalab HTTP/1.1/NA   200.0    1073.0
# 16       GET   css/index.css HTTP/1.1   304.0       NaN
# 17       GET    img/logo.png HTTP/1.1   304.0       NaN
# 18       GET              HTTP/1.1/NA   200.0    1040.0
# 19       GET   css/index.css HTTP/1.1   200.0     945.0
# 20       GET    img/logo.png HTTP/1.1   200.0   34463.0
# 21      POST      datalab HTTP/1.1/NA   200.0    1073.0
# 22       GET   css/index.css HTTP/1.1   304.0       NaN
# 23       GET    img/logo.png HTTP/1.1   304.0       NaN
# 24       GET              HTTP/1.1/NA   200.0    1040.0
# 25       GET   css/index.css HTTP/1.1   200.0     945.0
# 26       GET    img/logo.png HTTP/1.1   200.0   34463.0
# 27      POST      datalab HTTP/1.1/NA   200.0    1073.0
# 28       GET   css/index.css HTTP/1.1   304.0       NaN
# 29       GET    img/logo.png HTTP/1.1   304.0       NaN
# ...       ...                     ...     ...       ...
# 1116    POST      datalab HTTP/1.1/NA   200.0    1073.0
# 1117     GET   css/index.css HTTP/1.1   304.0       NaN
# 1118     GET    img/logo.png HTTP/1.1   304.0       NaN
# 1119    POST      datalab HTTP/1.1/NA   200.0    1073.0
# 1120     GET   css/index.css HTTP/1.1   304.0       NaN
# 1121     GET    img/logo.png HTTP/1.1   304.0       NaN
# 1122     GET              HTTP/1.1/NA   304.0       NaN
# 1123     GET   css/index.css HTTP/1.1   304.0       NaN
# 1124     GET    img/logo.png HTTP/1.1   304.0       NaN
# 1125    POST      datalab HTTP/1.1/NA   200.0    1073.0
# 1126     GET   css/index.css HTTP/1.1   304.0       NaN
# 1127     GET    img/logo.png HTTP/1.1   304.0       NaN
# 1128    POST      datalab HTTP/1.1/NA   200.0    1073.0
# 1129     GET   css/index.css HTTP/1.1   304.0       NaN
# 1130     GET    img/logo.png HTTP/1.1   304.0       NaN
# 1131     GET              HTTP/1.1/NA   304.0       NaN
# 1132     GET   css/index.css HTTP/1.1   304.0       NaN
# 1133     GET    img/logo.png HTTP/1.1   304.0       NaN
# 1134    POST      datalab HTTP/1.1/NA   200.0    1073.0
# 1135     GET   css/index.css HTTP/1.1   304.0       NaN
# 1136     GET    img/logo.png HTTP/1.1   304.0       NaN
# 1137    POST      datalab HTTP/1.1/NA   200.0    1073.0
# 1138     GET   css/index.css HTTP/1.1   304.0       NaN
# 1139     GET    img/logo.png HTTP/1.1   304.0       NaN
# 1140     GET              HTTP/1.1/NA   304.0       NaN
# 1141     GET   css/index.css HTTP/1.1   304.0       NaN
# 1142     GET    img/logo.png HTTP/1.1   304.0       NaN
# 1143    POST      datalab HTTP/1.1/NA   200.0    1073.0
# 1144     GET   css/index.css HTTP/1.1   304.0       NaN
# 1145     GET    img/logo.png HTTP/1.1   304.0       NaN
#
#                                    url  \
# 0                                  NaN
# 1            http://31.14.135.81:3000/
# 2            http://31.14.135.81:3000/
# 3            http://31.14.135.81:3000/
# 4            http://31.14.135.81:3000/
# 5            http://31.14.135.81:3000/
# 6                                  NaN
# 7            http://31.14.135.81:3000/
# 8            http://31.14.135.81:3000/
# 9            http://31.14.135.81:3000/
# 10           http://31.14.135.81:3000/
# 11           http://31.14.135.81:3000/
# 12                                 NaN
# 13           http://31.14.135.81:3000/
# 14           http://31.14.135.81:3000/
# 15           http://31.14.135.81:3000/
# 16           http://31.14.135.81:3000/
# 17           http://31.14.135.81:3000/
# 18                                 NaN
# 19           http://31.14.135.81:3000/
# 20           http://31.14.135.81:3000/
# 21           http://31.14.135.81:3000/
# 22           http://31.14.135.81:3000/
# 23           http://31.14.135.81:3000/
# 24                                 NaN
# 25           http://31.14.135.81:3000/
# 26           http://31.14.135.81:3000/
# 27           http://31.14.135.81:3000/
# 28           http://31.14.135.81:3000/
# 29           http://31.14.135.81:3000/
# ...                                ...
# 1116         http://31.14.135.81:3000/
# 1117         http://31.14.135.81:3000/
# 1118         http://31.14.135.81:3000/
# 1119  http://31.14.135.81:3000/datalab
# 1120         http://31.14.135.81:3000/
# 1121         http://31.14.135.81:3000/
# 1122                               NaN
# 1123         http://31.14.135.81:3000/
# 1124         http://31.14.135.81:3000/
# 1125         http://31.14.135.81:3000/
# 1126         http://31.14.135.81:3000/
# 1127         http://31.14.135.81:3000/
# 1128  http://31.14.135.81:3000/datalab
# 1129         http://31.14.135.81:3000/
# 1130         http://31.14.135.81:3000/
# 1131                               NaN
# 1132         http://31.14.135.81:3000/
# 1133         http://31.14.135.81:3000/
# 1134         http://31.14.135.81:3000/
# 1135         http://31.14.135.81:3000/
# 1136         http://31.14.135.81:3000/
# 1137  http://31.14.135.81:3000/datalab
# 1138         http://31.14.135.81:3000/
# 1139         http://31.14.135.81:3000/
# 1140                               NaN
# 1141         http://31.14.135.81:3000/
# 1142         http://31.14.135.81:3000/
# 1143         http://31.14.135.81:3000/
# 1144         http://31.14.135.81:3000/
# 1145         http://31.14.135.81:3000/
#
#                                                computer  timeR  attaque
# 0     datalab SELECT @@version Mozilla/5.0 (Macintos...   23.0        1
# 1     datalab SELECT @@version Mozilla/5.0 (Macintos...   10.0        1
# 2     datalab SELECT @@version Mozilla/5.0 (Macintos...    2.0        1
# 3     datalab SELECT @@version Mozilla/5.0 (Macintos...  180.0        1
# 4     datalab SELECT @@version Mozilla/5.0 (Macintos...    1.0        1
# 5     datalab SELECT @@version Mozilla/5.0 (Macintos...    1.0        1
# 6     datalab SELECT 1; #comment Mozilla/5.0 (Macint...    1.0        1
# 7     datalab SELECT 1; #comment Mozilla/5.0 (Macint...    5.0        1
# 8     datalab SELECT 1; #comment Mozilla/5.0 (Macint...    1.0        1
# 9     datalab SELECT 1; #comment Mozilla/5.0 (Macint...  171.0        1
# 10    datalab SELECT 1; #comment Mozilla/5.0 (Macint...    0.0        1
# 11    datalab SELECT 1; #comment Mozilla/5.0 (Macint...    0.0        1
# 12    datalab SELECT /*comment*/1; Mozilla/5.0 (Maci...    1.0        1
# 13    datalab SELECT /*comment*/1; Mozilla/5.0 (Maci...    1.0        1
# 14    datalab SELECT /*comment*/1; Mozilla/5.0 (Maci...    2.0        1
# 15    datalab SELECT /*comment*/1; Mozilla/5.0 (Maci...  141.0        1
# 16    datalab SELECT /*comment*/1; Mozilla/5.0 (Maci...    0.0        1
# 17    datalab SELECT /*comment*/1; Mozilla/5.0 (Maci...    0.0        1
# 18    datalab SELECT user(); Mozilla/5.0 (Macintosh;...    0.0        1
# 19    datalab SELECT user(); Mozilla/5.0 (Macintosh;...    3.0        1
# 20    datalab SELECT user(); Mozilla/5.0 (Macintosh;...    1.0        1
# 21    datalab SELECT user(); Mozilla/5.0 (Macintosh;...  173.0        1
# 22    datalab SELECT user(); Mozilla/5.0 (Macintosh;...    0.0        1
# 23    datalab SELECT user(); Mozilla/5.0 (Macintosh;...    0.0        1
# 24    datalab SELECT system_user(); Mozilla/5.0 (Mac...    1.0        1
# 25    datalab SELECT system_user(); Mozilla/5.0 (Mac...    1.0        1
# 26    datalab SELECT system_user(); Mozilla/5.0 (Mac...    0.0        1
# 27    datalab SELECT system_user(); Mozilla/5.0 (Mac...  165.0        1
# 28    datalab SELECT system_user(); Mozilla/5.0 (Mac...    0.0        1
# 29    datalab SELECT system_user(); Mozilla/5.0 (Mac...    0.0        1
# ...                                                 ...    ...      ...
# 1116  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...   91.0        0
# 1117  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    0.0        0
# 1118  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    5.0        0
# 1119  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...   91.0        0
# 1120  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    0.0        0
# 1121  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    1.0        0
# 1122  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    1.0        0
# 1123  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    0.0        0
# 1124  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    2.0        0
# 1125  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...   96.0        0
# 1126  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    0.0        0
# 1127  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    0.0        0
# 1128  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...   87.0        0
# 1129  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    0.0        0
# 1130  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    0.0        0
# 1131  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    0.0        0
# 1132  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    1.0        0
# 1133  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    0.0        0
# 1134  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...  163.0        0
# 1135  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    0.0        0
# 1136  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    0.0        0
# 1137  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...  164.0        0
# 1138  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    0.0        0
# 1139  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    0.0        0
# 1140  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    0.0        0
# 1141  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    0.0        0
# 1142  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    0.0        0
# 1143  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...  130.0        0
# 1144  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    0.0        0
# 1145  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_3...    1.0        0
#
# [1146 rows x 15 columns]

# %%
x=[]
for line in data_logs.computer.values:
    f1=get_len(line)
    f2=get_evil_char(line)
    f3=get_evil_word(line)
    x.append([f1,f2,f3])
print(x)
# Out:
# [[145, 2, 2], [145, 2, 2], [145, 2, 2], [145, 2, 2], [145, 2, 2], [145, 2, 2], [147, 1, 2], [147, 1, 2], [147, 1, 2], [147, 1, 2], [147, 1, 2], [147, 1, 2], [149, 2, 2], [149, 2, 2], [149, 2, 2], [149, 2, 2], [149, 2, 2], [149, 2, 2], [143, 0, 2], [143, 0, 2], [143, 0, 2], [143, 0, 2], [143, 0, 2], [143, 0, 2], [150, 0, 2], [150, 0, 2], [150, 0, 2], [150, 0, 2], [150, 0, 2], [150, 0, 2], [164, 0, 5], [164, 0, 5], [164, 0, 5], [164, 0, 5], [164, 0, 5], [164, 0, 5], [180, 1, 7], [180, 1, 7], [180, 1, 7], [180, 1, 7], [180, 1, 7], [180, 1, 7], [838, 4, 19], [838, 4, 19], [838, 4, 19], [838, 4, 19], [838, 4, 19], [838, 4, 19], [309, 7, 11], [309, 7, 11], [309, 7, 11], [309, 7, 11], [309, 7, 11], [309, 7, 11], [146, 0, 1], [146, 0, 1], [146, 0, 1], [146, 0, 1], [146, 0, 1], [146, 0, 1], [201, 3, 4], [201, 3, 4], [201, 3, 4], [201, 3, 4], [201, 3, 4], [201, 3, 4], [169, 1, 3], [169, 1, 3], [169, 1, 3], [169, 1, 3], [169, 1, 3], [169, 1, 3], [276, 6, 6], [276, 6, 6], [276, 6, 6], [276, 6, 6], [276, 6, 6], [276, 6, 6], [261, 6, 5], [261, 6, 5], [261, 6, 5], [261, 6, 5], [261, 6, 5], [261, 6, 5], [275, 6, 9], [275, 6, 9], [275, 6, 9], [275, 6, 9], [275, 6, 9], [275, 6, 9], [210, 1, 8], [210, 1, 8], [210, 1, 8], [210, 1, 8], [210, 1, 8], [210, 1, 8], [210, 1, 8], [210, 1, 8], [210, 1, 8], [210, 1, 8], [210, 1, 8], [210, 1, 8], [169, 3, 1], [169, 3, 1], [169, 3, 1], [169, 3, 1], [169, 3, 1], [169, 3, 1], [154, 1, 1], [154, 1, 1], [154, 1, 1], [154, 1, 1], [154, 1, 1], [154, 1, 1], [154, 1, 1], [154, 1, 1], [154, 1, 1], [154, 1, 1], [154, 1, 1], [154, 1, 1], [157, 1, 1], [157, 1, 1], [157, 1, 1], [157, 1, 1], [157, 1, 1], [157, 1, 1], [160, 3, 1], [160, 3, 1], [160, 3, 1], [160, 3, 1], [160, 3, 1], [160, 3, 1], [166, 2, 1], [166, 2, 1], [166, 2, 1], [166, 2, 1], [166, 2, 1], [166, 2, 1], [156, 2, 1], [156, 2, 1], [156, 2, 1], [156, 2, 1], [156, 2, 1], [156, 2, 1], [164, 4, 1], [164, 4, 1], [164, 4, 1], [164, 4, 1], [164, 4, 1], [170, 5, 1], [170, 5, 1], [170, 5, 1], [170, 5, 1], [170, 5, 1], [172, 7, 1], [172, 7, 1], [172, 7, 1], [172, 7, 1], [172, 7, 1], [186, 6, 1], [186, 6, 1], [186, 6, 1], [186, 6, 1], [186, 6, 1], [186, 6, 1], [159, 1, 1], [159, 1, 1], [159, 1, 1], [159, 1, 1], [159, 1, 1], [159, 1, 1], [164, 2, 1], [164, 2, 1], [164, 2, 1], [164, 2, 1], [164, 2, 1], [164, 2, 1], [157, 3, 1], [157, 3, 1], [157, 3, 1], [157, 3, 1], [157, 3, 1], [157, 3, 1], [214, 3, 1], [214, 3, 1], [214, 3, 1], [214, 3, 1], [214, 3, 1], [214, 3, 1], [210, 4, 2], [210, 4, 2], [210, 4, 2], [210, 4, 2], [210, 4, 2], [210, 4, 2], [147, 2, 3], [147, 2, 3], [147, 2, 3], [147, 2, 3], [147, 2, 3], [147, 2, 3], [176, 3, 1], [176, 3, 1], [176, 3, 1], [176, 3, 1], [176, 3, 1], [176, 3, 1], [152, 1, 1], [152, 1, 1], [152, 1, 1], [152, 1, 1], [152, 1, 1], [152, 1, 1], [177, 6, 0], [177, 6, 0], [177, 6, 0], [177, 6, 0], [177, 6, 0], [146, 2, 1], [146, 2, 1], [146, 2, 1], [146, 2, 1], [146, 2, 1], [146, 2, 1], [162, 2, 1], [162, 2, 1], [162, 2, 1], [162, 2, 1], [162, 2, 1], [162, 2, 1], [134, 0, 1], [134, 0, 1], [134, 0, 1], [134, 0, 1], [134, 0, 1], [134, 0, 1], [82, 0, 0], [82, 0, 0], [82, 0, 0], [82, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0], [120, 0, 0],  ...

# %%
y=data_logs.attaque.values
print(y)
# Out:
# [1 1 1 ..., 0 0 0]

# %%
from sklearn import metrics
def do_metrics(y_test,y_pred):
    print ("metrics.accuracy_score:")
    print (metrics.accuracy_score(y_test, y_pred))
    print ("metrics.confusion_matrix:")
    print (metrics.confusion_matrix(y_test, y_pred))
    print ("metrics.precision_score:")
    print (metrics.precision_score(y_test, y_pred))
    print ("metrics.recall_score:")
    print (metrics.recall_score(y_test, y_pred))
    print ("metrics.f1_score:")
    print (metrics.f1_score(y_test,y_pred))

# %%
from sklearn import cross_validation
from sklearn import datasets
from sklearn import svm
from sklearn.externals import  joblib
import matplotlib.pyplot as plt
x_train, x_test, y_train, y_test = cross_validation.train_test_split(x,y, test_size=0.4, random_state=0)
clf = svm.SVC(kernel='linear', C=1).fit(x_train, y_train)
y_pred = clf.predict(x_test)
do_metrics(y_test, y_pred)
# Out:
# metrics.accuracy_score:
# 1.0
# metrics.confusion_matrix:
# [[373   0]
#  [  0  86]]
# metrics.precision_score:
# 1.0
# metrics.recall_score:
# 1.0
# metrics.f1_score:
# 1.0

# %%
labels = ['attaque', 'no attaque']
cm = metrics.confusion_matrix(y_test, y_pred)

def plot_cm(cm, labels):
    
    # Compute percentanges
    percent = (cm*100.0)/np.array(np.matrix(cm.sum(axis=1)).T)  # Derp, I'm sure there's a better way
    
    print ('Confusion Matrix Stats')
    for i, label_i in enumerate(labels):
        for j, label_j in enumerate(labels):
            print ("%s/%s: %.2f%% (%d/%d)" % (label_i, label_j, (percent[i][j]), cm[i][j], cm[i].sum()))

    # Show confusion matrix
    # Thanks kermit666 from stackoverflow :)
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.grid(b=False)
    cax = ax.matshow(percent, cmap='coolwarm')
    plt.title('Confusion matrix of the classifier')
    fig.colorbar(cax)
    ax.set_xticklabels([''] + labels)
    ax.set_yticklabels([''] + labels)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

plot_cm(cm, labels)
# Out:
# Confusion Matrix Stats
# attaque/attaque: 100.00% (373/373)
# attaque/no attaque: 0.00% (0/373)
# no attaque/attaque: 0.00% (0/86)
# no attaque/no attaque: 100.00% (86/86)
# [[373   0]
#  [  0  86]]
